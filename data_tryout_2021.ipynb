# %%
print("hello world")
# Out:
# hello world

# %%
import json

with open('2021_data/dev_set_task1.txt') as json_file:
    data = json.load(json_file)

# %%
data
# Out:
# [{'id': '62_batch_2',
#   'labels': [],
#   'text': '*President* Biden?\n\nPlease, no.\n'},
#  {'id': '111_batch_2',
#   'labels': ['Loaded Language', 'Name calling/Labeling'],
#   'text': 'JOE  VERSUS THE VOLCANIC KREMLIN DON\n\n"WILL YOU SHUT UP, MAN?"\n\nLORD OF THE LIES'},
#  {'id': '167_batch_2',
#   'labels': [],
#   'text': 'ANTI-VAXXERS BE LIKE... \n\nHANG ON A SEC - JUST COLLECTING MY FACTS'},
#  {'id': '93_batch_2', 'labels': [], 'text': 'VIRUS BINGO\nFREE 32 SPACE\n'},
#  {'id': '153_batch_2',
#   'labels': ['Exaggeration/Minimisation',
#    'Loaded Language',
#    'Name calling/Labeling'],
#   'text': "Never thought l'd die fighting IRRESPONSIBLY RUSHED VACCINES side by side with an ANTIVAXXER\n\nWhat about side by side with a friend?\n\nDON'T YOU HAVE A KID'S FUNERAL TO ATTEND OR SOMETHING?"},
#  {'id': '173_batch_2',
#   'labels': ["Misrepresentation of Someone's Position (Straw Man)",
#    'Exaggeration/Minimisation',
#    'Loaded Language',
#    'Name calling/Labeling'],
#   'text': 'Anti-Vaxers keep saying dumb things, like "Vaccines aren\'t 100% effective, so they are useless!"\n\nParachutes aren\'t 100% effective either, but\nwearing one is a damn good idea...'},
#  {'id': '9_batch_2',
#   'labels': ['Smears', 'Doubt', 'Loaded Language', 'Name calling/Labeling'],
#   'text': 'Definition Of Stupid:\n\nKnowing The Truth, Seeing The Truth, but still Believing in TRUDEAU!\n'},
#  {'id': '33_batch_2',
#   'labels': ['Loaded Language',
#    'Name calling/Labeling',
#    'Causal Oversimplification'],
#   'text': 'OH, LOOK... ACTING LIKE A MORON IS GENETIC'},
#  {'id': '76_batch_2', 'labels': [], 'text': 'AFTER FIRST DEBATE WITH TRUMP\n'},
#  {'id': '172_batch_2',
#   'labels': ['Appeal to fear/prejudice',
#    "Misrepresentation of Someone's Position (Straw Man)",
#    'Loaded Language',
#    'Name calling/Labeling'],
#   'text': 'BILL GATES HAS A SECRET EUGENICS PLAN TO DEPOPULATE THE WORLD THROUGH VACCINES!\n\nBECAUSE ALL EVIL VILLAINS ANNOUNCE THEIR MURDEROUS PLANS IN TED TALK PRESENTATIONS.'},
#  {'id': '133_batch_2',
#   'labels': ['Repetition'],
#   'text': '"LAW AND ORDER"\n\nPLEADED GUILTY\n\nCONVICTED\n\nCONVICTED\n\nCONVICTED\n\nCONVICTED\n\nINDICTED'},
#  {'id': '189_batch_2',
#   'labels': ['Loaded Language', 'Name calling/Labeling'],
#   'text': 'This is so creepy...\nAlso, the guy behind Joe, Matt Trowbridge, was just caught on video trying to have sex with a minor.'},
#  {'id': '19_batch_2',
#   'labels': ['Exaggeration/Minimisation'],
#   'text': 'I say we remove the sculpture "The Thinker"\n\nIt\'s offensive to all the people who don\'t think'},
#  {'id': '135_batch_2',
#   'labels': ['Slogans', 'Name calling/Labeling', 'Flag-waving'],
#   'text': 'TRUMP BODY COUNT\nSeptember 16, 2020\n200,770\n\nTRUMPS IDEA OF WINNING\n\nTRUMP\n-2020-\nKEEP AMERICA GREAT'},
#  {'id': '116_batch_2',
#   'labels': ['Thought-terminating cliché',
#    'Smears',
#    'Loaded Language',
#    'Doubt',
#    'Whataboutism'],
#   'text': 'LAST NIGHT, TRUMP BRAGGED ABOUT CANCELLING KILLING RACIAL SENSITIVITY TRAININGS, SAYING AMERICA DOESN\'T NEED \'EM... AND THEN REFUSED TO CONDEMN WHITE SUPREMACISTS AND TOLD THEM TO "STAND BY."\n\nYOU CAN\'T MAKE THIS STUFF UP, FOLKS.'},
#  {'id': '142_batch_2',
#   'labels': ['Loaded Language', 'Name calling/Labeling'],
#   'text': 'How ANTI-VAXXERS THINK VACCINES ARE MADE\n\nProfessor, I found this weird blue fluid in a jar marked TOXINS.\n\nExcellent, Dr Evil!\nToss it ALL in... THE VACCINE VAT!'},
#  {'id': '30_batch_2',
#   'labels': [],
#   'text': 'STILL MORE COHERENT THAN JOE BIDEN'},
#  {'id': '136_batch_2',
#   'labels': ['Appeal to fear/prejudice', 'Loaded Language', 'Flag-waving'],
#   'text': "What level of hell have we entered where our tax dollars are used to fund this vehicle equipped with a 'heat ray' & a 'sound cannon’ to attack U.S. citizens on the streets of America?"},
#  {'id': '87_batch_2',
#   'labels': ['Loaded Language'],
#   'text': 'This offends me.\n\nMario Cuomo Bridge\nKEEP LEFT\n\nTear it down!\n'},
#  {'id': '81_batch_2',
#   'labels': ['Slogans', 'Bandwagon', 'Flag-waving'],
#   'text': "GET IN!\n\nWE'RE MAKING AMERICA GREAT!\n"},
#  {'id': '78_batch_2',
#   'labels': ['Loaded Language', 'Flag-waving'],
#   'text': 'HONG KONG\n\nWAVES AMERICAN FLAG TO FIGHT FOR FREEDOM \n\nPORTLAND\n\nWAVES COMMUNIST FLAG TO FIGHT AGAINST FREEDOM\n'},
#  {'id': '114_batch_2',
#   'labels': ['Name calling/Labeling'],
#   'text': 'TRUMP SAID THE VIRUS WOULD DISAPPEAR \n\nHE WAS TALKING ABOUT HIMSELF'},
#  {'id': '106_batch_2',
#   'labels': ['Smears', 'Loaded Language'],
#   'text': 'The President did not "catch" coronavirus.\nHe IGNORED the advice of doctors, MOCKED the science, put himself in RISKY situations and once exposed, he refused to self Quarantine and ENDANGERED the lives of hundreds of people around him.\n'},
#  {'id': '53_batch_2',
#   'labels': ['Doubt', 'Loaded Language'],
#   'text': 'WILL TRUMP EVER CONDEMN HATE?! \n\n5MINUTES LATER...\nI HOPE HE DIES OF COVID!\n\n'},
#  {'id': '31_batch_2',
#   'labels': ['Exaggeration/Minimisation'],
#   'text': 'Putting a helmet on a head without a brain is like putting a security system on an outhouse.\n'},
#  {'id': '24_batch_2',
#   'labels': ['Doubt',
#    'Whataboutism',
#    'Loaded Language',
#    'Name calling/Labeling'],
#   'text': 'Get in loser we\'re deleting meme pages for "hate speech" but leaving up kiddie porn and videos of people dying'},
#  {'id': '137_batch_2',
#   'labels': ['Loaded Language'],
#   'text': 'CAN I GET A FUCK TRUMP'},
#  {'id': '65_batch_2',
#   'labels': ['Smears', 'Exaggeration/Minimisation'],
#   'text': 'Just when you think Democrat ethics, honesty, integrity and behavior have hit rock bottom, they blast through the rock bed... to a never-before-seen depth.\n'},
#  {'id': '155_batch_2',
#   'labels': [],
#   'text': "Unvaccinated Body: *Exists*\n\nNear extinct and easily preventable diseases:\nIt's Free Real Estate"},
#  {'id': '46_batch_2',
#   'labels': ['Loaded Language',
#    'Appeal to authority',
#    "Misrepresentation of Someone's Position (Straw Man)"],
#   'text': '"The phrase Black Lives Matter suggests racial superiority.\nIt excludes the importance of anybody else\'s life."\n"THAT IS RACISM DEFINED."\nSHERIFF DAVID CLARKE\n'},
#  {'id': '134_batch_2',
#   'labels': ['Smears', 'Appeal to authority', 'Name calling/Labeling'],
#   'text': "Professionals have determined that Trump speaks at a 4th grade level.\n\nIt's no wonder so many Republicans think he's a genius."},
#  {'id': '79_batch_2',
#   'labels': [],
#   'text': 'HOW TO BREAK UP A  BLACKLIVESMATTER PROTEST!\n\nARE YOU MY DAD?\n'},
#  {'id': '52_batch_2',
#   'labels': [],
#   'text': 'DONT WORRY \nIM ALSO ABOUT TO TEST POSITIVE FOR A 2ND TERM!\n'},
#  {'id': '141_batch_2',
#   'labels': ['Smears', 'Loaded Language', 'Name calling/Labeling'],
#   'text': 'If we stop testing for stupid, Will TRUMP be less stupid?'},
#  {'id': '60_batch_2', 'labels': [], 'text': 'BIDEN BOAT PARADE\n2020\n'},
#  {'id': '91_batch_2', 'labels': [], 'text': 'I HAVE THE HOAX\n'},
#  {'id': '129_batch_2',
#   'labels': ['Smears'],
#   'text': 'THE MORE TRUMP SPEAKS, THE LESS BIDEN NEEDS TO'},
#  {'id': '187_batch_2',
#   'labels': ['Smears', 'Loaded Language', 'Name calling/Labeling'],
#   'text': 'Conspiracy theorists are not skeptical\n\nThey are aggressively gullible'},
#  {'id': '119_batch_2',
#   'labels': [],
#   'text': 'NOVEMBER 3, 2020 \nTHE DAY THE CIRCUS LEAVES TOWN'},
#  {'id': '56_batch_2',
#   'labels': ['Doubt', 'Whataboutism', 'Name calling/Labeling'],
#   'text': 'Eagle-eyed sleuths will be able to identify which woman of Catholic faith Senate democrats unanimously found was:\nACCEPTABLE in 2009, and which one was...\nUNACCEPTABLE in 2020\n\nSonia Sotomayor\nAmy Coney Barrett\n'},
#  {'id': '121_batch_2',
#   'labels': ['Repetition', 'Smears', 'Loaded Language'],
#   'text': 'He cheats at golf.\nHe cheated the draft.\nHe cheats on his taxes.\nHe cheated on his wives.\nHe cheated on his loans.\n\nHe cheated his charities.\nHe cheated his contractors.\nHe cheated Trump U students.\nHe cheated to get elected in 2016.\nHe will cheat again in 2020!'},
#  {'id': '109_batch_2',
#   'labels': ['Loaded Language', 'Name calling/Labeling'],
#   'text': '"I\'m racist enough, I\'m homophobic enough, and doggone it, Mother likes me."\n\nDaily Affirmations with Mike'},
#  {'id': '43_batch_2',
#   'labels': ['Smears',
#    'Exaggeration/Minimisation',
#    'Loaded Language',
#    'Name calling/Labeling',
#    'Flag-waving'],
#   'text': "YOU MAY NOT THINK THE PMO IS A TOTAL EMBARRASSMENT TO CANADA but it's trudeau.\n"},
#  {'id': '18_batch_2',
#   'labels': ['Repetition',
#    'Smears',
#    'Loaded Language',
#    'Name calling/Labeling',
#    'Bandwagon'],
#   'text': "Where i'm gQing the rest will follow\n\nTHE TRUD Convicted of MURDER\n\n**WANTED** for treason to CANADA\n**WANTED** for crimes to Canadian citizens\n\n**WANTED** for child/human trafficking\n**WANTED** for pedophilia\n\nGITMO\n"},
#  {'id': '175_batch_2',
#   'labels': ['Doubt', 'Name calling/Labeling'],
#   'text': "She had measles and she didn't die\n\nMEASLES ISN'T DANGEROUS\n\nHe went to war and he didn't die\n\nWAR ISN'T DANGEROUS"},
#  {'id': '95_batch_2', 'labels': [], 'text': 'WILL SHE MAKE HIM CRY?\n'},
#  {'id': '34_batch_2',
#   'labels': ['Smears', 'Loaded Language', 'Name calling/Labeling'],
#   'text': 'I AM TOTALLY DISGUSTED. 50 YEARS AGO WE HUNTED AND KILLED COMMIES.\nTODAY,  WE LET THEM RUN STATES AND TELL US WHAT WE CAN DO.\nWHERE WE CAN GO, WHAT WE CAN BUY.\nWTF HAPPENED?\n'},
#  {'id': '2_batch_2',
#   'labels': [],
#   'text': 'How to vaccinate Cattle\n\nHow to vaccinate, ahem test, the Herd'},
#  {'id': '174_batch_2',
#   'labels': ['Name calling/Labeling'],
#   'text': 'Statue honoring those brave men & women who refused to wear a mask'},
#  {'id': '108_batch_2',
#   'labels': ['Loaded Language'],
#   'text': '"I HAVE A HUNCH IT\'S GOING TO DISAPPEAR, ONE DAY, IT\'S LIKE A MIRACLE, IT WILL DISAPPEAR"\n\nPOSITIVE\n\n'},
#  {'id': '158_batch_2',
#   'labels': ['Whataboutism', 'Name calling/Labeling'],
#   'text': "Not wearing a mask because that's for the sheep.\n\nUsing social media like the other 3 billion people out there"},
#  {'id': '6_batch_2',
#   'labels': [],
#   'text': 'WHAT A LOCKDOWN SHOULD ACTUALLY LOOK LIKE\n'},
#  {'id': '72_batch_2',
#   'labels': [],
#   'text': 'WAITING FOR BIDEN TO DEBATE LIKE...\n\n'},
#  {'id': '110_batch_2',
#   'labels': ['Smears',
#    'Exaggeration/Minimisation',
#    'Loaded Language',
#    'Name calling/Labeling',
#    'Doubt'],
#   'text': '"It affects virtually nobody. It\'s an amazing thing."\n-Donald Trump 9/22/20\nDear Americans. \nI often wonder: Is your president aware that the whole world is listening in to every one of his stupid statements? \nIf he isn\'t, perhaps someone would be so good as to inform him?'},
#  {'id': '112_batch_2',
#   'labels': ['Name calling/Labeling', 'Glittering generalities (Virtue)'],
#   'text': 'Joe Biden has pulled all negative ads out of respect for Trump.\nJoe Biden is taking down his negative ads, going all-positive, the New York Times reports.\nThat is what class and leadership looks like. \nDo you agree?'},
#  {'id': '159_batch_2',
#   'labels': ['Appeal to fear/prejudice'],
#   'text': "It's a good thing my parents didn't vaccinate me.\n\nSomething really bad might have happened!"},
#  {'id': '191_batch_2',
#   'labels': ['Smears', 'Name calling/Labeling'],
#   'text': 'ANTIFA\n\n"A courageous group of Americans."\n- Joe Biden (Apr 23, 2019)'},
#  {'id': '40_batch_2',
#   'labels': ['Reductio ad hitlerum', 'Slogans', 'Name calling/Labeling'],
#   'text': "LIVES MATTER\n\nIf you need a color in front of those words you're a racist\n"},
#  {'id': '90_batch_2',
#   'labels': ['Smears', 'Doubt', 'Loaded Language'],
#   'text': "Has anyone heard these two condemning the violence,\nrioting, looting & arson that has been taking place across the U.S.?\nI haven't.\n\n"},
#  {'id': '115_batch_2',
#   'labels': ['Smears', 'Loaded Language', 'Name calling/Labeling'],
#   'text': "Let's get Fu*king Real at this Point...\nPresident Trump is Mentally Sick, Yes -- Truly ill in how he manages his Financial Life and his handling of Whitehouse policy and management !!!"},
#  {'id': '128_batch_2',
#   'labels': ['Smears', 'Loaded Language', 'Name calling/Labeling'],
#   'text': 'A whoremonger, a pervert, and a pedophile walk into a bar. \nThe bartender asks, "Your regular, Mr. Trump?"'},
#  {'id': '92_batch_2',
#   'labels': ['Loaded Language', 'Name calling/Labeling'],
#   'text': 'Deceitful\nObnoxious\nNarcissist\nArrogant\nLying\nDishonest\n\nTactless\nRacists\nUneducated\nMisogynistic\nPompous\n'},
#  {'id': '139_batch_2',
#   'labels': ['Smears', 'Appeal to fear/prejudice', 'Loaded Language'],
#   'text': 'Got 195,000 + Americans KILLED.\nFought scientists and doctors every step of the way.\n\nGot 20,000,000 Americans health care.\nRepublicans fought them every step of the way. '}]

# %%
labels = []
for da in data:
    labels.append(da['labels'])
labels
# Out:
# [[],
#  ['Loaded Language', 'Name calling/Labeling'],
#  [],
#  [],
#  ['Exaggeration/Minimisation', 'Loaded Language', 'Name calling/Labeling'],
#  ["Misrepresentation of Someone's Position (Straw Man)",
#   'Exaggeration/Minimisation',
#   'Loaded Language',
#   'Name calling/Labeling'],
#  ['Smears', 'Doubt', 'Loaded Language', 'Name calling/Labeling'],
#  ['Loaded Language', 'Name calling/Labeling', 'Causal Oversimplification'],
#  [],
#  ['Appeal to fear/prejudice',
#   "Misrepresentation of Someone's Position (Straw Man)",
#   'Loaded Language',
#   'Name calling/Labeling'],
#  ['Repetition'],
#  ['Loaded Language', 'Name calling/Labeling'],
#  ['Exaggeration/Minimisation'],
#  ['Slogans', 'Name calling/Labeling', 'Flag-waving'],
#  ['Thought-terminating cliché',
#   'Smears',
#   'Loaded Language',
#   'Doubt',
#   'Whataboutism'],
#  ['Loaded Language', 'Name calling/Labeling'],
#  [],
#  ['Appeal to fear/prejudice', 'Loaded Language', 'Flag-waving'],
#  ['Loaded Language'],
#  ['Slogans', 'Bandwagon', 'Flag-waving'],
#  ['Loaded Language', 'Flag-waving'],
#  ['Name calling/Labeling'],
#  ['Smears', 'Loaded Language'],
#  ['Doubt', 'Loaded Language'],
#  ['Exaggeration/Minimisation'],
#  ['Doubt', 'Whataboutism', 'Loaded Language', 'Name calling/Labeling'],
#  ['Loaded Language'],
#  ['Smears', 'Exaggeration/Minimisation'],
#  [],
#  ['Loaded Language',
#   'Appeal to authority',
#   "Misrepresentation of Someone's Position (Straw Man)"],
#  ['Smears', 'Appeal to authority', 'Name calling/Labeling'],
#  [],
#  [],
#  ['Smears', 'Loaded Language', 'Name calling/Labeling'],
#  [],
#  [],
#  ['Smears'],
#  ['Smears', 'Loaded Language', 'Name calling/Labeling'],
#  [],
#  ['Doubt', 'Whataboutism', 'Name calling/Labeling'],
#  ['Repetition', 'Smears', 'Loaded Language'],
#  ['Loaded Language', 'Name calling/Labeling'],
#  ['Smears',
#   'Exaggeration/Minimisation',
#   'Loaded Language',
#   'Name calling/Labeling',
#   'Flag-waving'],
#  ['Repetition',
#   'Smears',
#   'Loaded Language',
#   'Name calling/Labeling',
#   'Bandwagon'],
#  ['Doubt', 'Name calling/Labeling'],
#  [],
#  ['Smears', 'Loaded Language', 'Name calling/Labeling'],
#  [],
#  ['Name calling/Labeling'],
#  ['Loaded Language'],
#  ['Whataboutism', 'Name calling/Labeling'],
#  [],
#  [],
#  ['Smears',
#   'Exaggeration/Minimisation',
#   'Loaded Language',
#   'Name calling/Labeling',
#   'Doubt'],
#  ['Name calling/Labeling', 'Glittering generalities (Virtue)'],
#  ['Appeal to fear/prejudice'],
#  ['Smears', 'Name calling/Labeling'],
#  ['Reductio ad hitlerum', 'Slogans', 'Name calling/Labeling'],
#  ['Smears', 'Doubt', 'Loaded Language'],
#  ['Smears', 'Loaded Language', 'Name calling/Labeling'],
#  ['Smears', 'Loaded Language', 'Name calling/Labeling'],
#  ['Loaded Language', 'Name calling/Labeling'],
#  ['Smears', 'Appeal to fear/prejudice', 'Loaded Language']]

# %%
count = 0
for label in labels:
    if len(label)== 0:
        count += 1
    
count
# Out:
# 15

# %%
len(data)
# Out:
# 63

# %%
import json

with open('2021_data/training_set_task1.txt') as json_file:
    data_train = json.load(json_file)
    
data_train
# Out:
# [{'id': '128',
#   'labels': ['Black-and-white Fallacy/Dictatorship'],
#   'text': 'THERE ARE ONLY TWO GENDERS\n\nFEMALE \n\nMALE\n'},
#  {'id': '189', 'labels': [], 'text': 'This is not an accident!'},
#  {'id': '96',
#   'labels': ['Loaded Language', 'Name calling/Labeling', 'Slogans', 'Smears'],
#   'text': "SO BERNIE BROS HAVEN'T COMMITTED VIOLENCE EH?\n\nPOWER COMES FROM THE BARREL OF A GUN, COMRADES.\n\nWHAT ABOUT THE ONE WHO SHOT CONGRESSMAN SCALISE OR THE DAYTON OHIO MASS SHOOTER?\n"},
#  {'id': '154',
#   'labels': ['Causal Oversimplification',
#    'Loaded Language',
#    'Name calling/Labeling',
#    'Slogans',
#    'Smears'],
#   'text': "PATHETIC\n\nThe Cowardly Asshole\nWeak Failure!!!\n\nImpeach it again!!!\n\n# 45 the coward s afraid of strong women!!\n\nPOLITICUSUSA.COM\nChildish Trump Won't Meet With Pelosi On Coronavirus\nBecause He Doesn't Like Her\n"},
#  {'id': '15',
#   'labels': [],
#   'text': 'WHO TRUMP REPRESENTS\n\nWHO DEMOCRATS REPRESENT\n'},
#  {'id': '169',
#   'labels': ['Appeal to fear/prejudice',
#    'Causal Oversimplification',
#    'Exaggeration/Minimisation',
#    'Slogans'],
#   'text': 'Our elders were called to war to save lives.\nWe are being called to sit on the couch to save theirs.\nWe can do this.\n'},
#  {'id': '145',
#   'labels': ['Loaded Language',
#    'Name calling/Labeling',
#    'Reductio ad hitlerum',
#    'Smears'],
#   'text': "Adolf Hitler\n• Believed state power would fix Germany\n• Proposed gun control\n• Promised a political revolution\n• Called himself socialist\n• Blamed Jews for Germany's problems\n• Wanted a heavily regulated economy\n\nBernie Sanders\n• Believes state power will fix America\n• Proposes gun control\n• Promises a political revolution\n• Calls himself socialist\n• Blames the rich for America's problems\n• Wants a heavily regulated economy"},
#  {'id': '73',
#   'labels': ['Loaded Language', 'Name calling/Labeling', 'Smears'],
#   'text': 'CALM DOWN LITTLE TRUMP HATER\nI FOUND YOUR BINKY\n'},
#  {'id': '153',
#   'labels': ['Loaded Language', 'Name calling/Labeling', 'Repetition'],
#   'text': "UGLY INSIDE & OUT\n\nRACIST, LIAR with NO ETHICS, and he's NUTS\n\nDangerously STUPID and Certifiably CRAZY\n\nUGLY INSIDE & OUT"},
#  {'id': '130',
#   'labels': ['Causal Oversimplification',
#    'Glittering generalities (Virtue)',
#    'Loaded Language',
#    'Name calling/Labeling'],
#   'text': 'WHEN YOUR TAXES ARE FINALLY USED TO KILL TERRORISTS...\n\nINSTEAD OF FUNDING THEM!\nTRUMP 2020\n'},
#  {'id': '104',
#   'labels': ['Appeal to fear/prejudice',
#    'Loaded Language',
#    'Slogans',
#    'Smears'],
#   'text': "SCARE TATICS BY THE LEFT.\n\nClose businesses\nClose stadiums\nDestroy the stock market\nTry to eliminate TRUMP RALLIES.\nIs this part of a larger CONSPIRÁCY?\nCORONAVIRUS\nDON'T PANIC..\nTHINK AMERICA!\n"},
#  {'id': '146',
#   'labels': ['Causal Oversimplification',
#    'Loaded Language',
#    'Name calling/Labeling'],
#   'text': "THOSE LIBERALS HATE ME\n\nIT'S BECAUSE I'M BLACK ISN'T IT ?\n"},
#  {'id': '188',
#   'labels': ["Misrepresentation of Someone's Position (Straw Man)"],
#   'text': 'If you think "they" are hiding the cure for cancer, but you discourage people from getting the HPV and Hep. B vaccines...\n\nthen YOU are "they."\n'},
#  {'id': '175',
#   'labels': ['Loaded Language', 'Name calling/Labeling'],
#   'text': 'A society that keeps cures a secret, in an effort to sell medications for huge profits, is not a civilised society; it is a mental institution ruled over by phsychopaths.\n'},
#  {'id': '168',
#   'labels': ['Loaded Language', 'Slogans'],
#   'text': 'ITS NOT THE HERO WE NEED\n\nBUT THE HERO WE DESERVE\n'},
#  {'id': '106',
#   'labels': ['Exaggeration/Minimisation',
#    'Glittering generalities (Virtue)',
#    'Loaded Language',
#    "Misrepresentation of Someone's Position (Straw Man)",
#    'Name calling/Labeling',
#    'Smears'],
#   'text': 'TRUMP CURES CORONAVIRUS!\n\nCURING CORONA VIRUS IS RACIST\n\nWE HAVE THE RIGHT TO DIE FROM OUR CORONAVIRUS\n\nDEMOCRATS ARE OUTRAGED!\n'},
#  {'id': '66',
#   'labels': ['Appeal to fear/prejudice', 'Loaded Language', 'Slogans'],
#   'text': "UN\n\nNew York UN Office Recruits Paramilitary Troops for 'Disarmament' and Reintegration' of US Civilians\n\nWELCOME TO AMERICA\n\n"},
#  {'id': '129',
#   'labels': ['Exaggeration/Minimisation', 'Loaded Language', 'Smears'],
#   'text': "HIROSHIMA\n1945\n2016\n\nDETROIT\n1945\n2016\n\nMORAL OF THE STORY...\nIT'S EASIER TO COME BACK FROM A NUCLEAR BOMB THAN DECADES OF DEMOCRATIC LEADERSHIP\n"},
#  {'id': '2',
#   'labels': ['Doubt', 'Loaded Language', 'Name calling/Labeling', 'Smears'],
#   'text': 'Reminder: This building in Oklahoma City was blown up and destroyed just 4 days before Hillary Clinton was to be indicted in the Whitewater scandal. \nAll documents lost!\n'},
#  {'id': '65',
#   'labels': ['Loaded Language'],
#   'text': 'How to tell if your dog is involved in a sex scandal\n'},
#  {'id': '8',
#   'labels': ['Repetition'],
#   'text': 'I PROMISE.\n\nI PROMISE.\n\nI PROMISE.\n\nI DELIVER.\n'},
#  {'id': '127',
#   'labels': ['Loaded Language',
#    "Misrepresentation of Someone's Position (Straw Man)",
#    'Name calling/Labeling',
#    'Obfuscation, Intentional vagueness, Confusion',
#    'Smears'],
#   'text': 'THE PEOPLE WHO ONCE CALLED OUR SOLDIERS BABY KILLERS\n\nNOW MARCH FOR THE RIGHT TO KILL BABIES\n'},
#  {'id': '142',
#   'labels': [],
#   'text': 'DEMOCRATS STARTED WEARING ALL WHITE...\n\nAGAIN'},
#  {'id': '29',
#   'labels': ['Loaded Language', 'Slogans'],
#   'text': 'ALL I WANT FOR CHRISTMAS IS JUSTICE\n'},
#  {'id': '131',
#   'labels': ['Loaded Language',
#    'Name calling/Labeling',
#    'Smears',
#    'Whataboutism'],
#   'text': 'LEFTISTS THINK INJECTING CATTLE WITH HORMONES IS EVIL\n\nBUT THINK INJECTING KIDS WITH HORMONES TO CHANGE THEIR GENDER IS JUST FINE\n'},
#  {'id': '176', 'labels': [], 'text': 'CORRECT:\n\nTHE WORLD\n\nCHINA\n'},
#  {'id': '125',
#   'labels': ['Loaded Language', 'Name calling/Labeling'],
#   'text': 'I HATE TRUMP\n\nMOST TERRORIST DO'},
#  {'id': '182',
#   'labels': ['Exaggeration/Minimisation', 'Name calling/Labeling', 'Smears'],
#   'text': 'The most costly errors in all of history\n\nWorld Health Organization (WHO)\nPreliminary investigations conducted by the Chinese authorities have found no clear evidence of human-to-human transmission of the novel #coronavirus (2019-nCoV) identified in #Wuhan, #China\n14 Jan 2020\n\nWORLD NEWS FEBRUARY 3, 2020 / 10:33 PM / 2 MONTHS AGO\nWHO chief says widespread travel bans not needed to beat China virus\n'},
#  {'id': '178',
#   'labels': [],
#   'text': 'COVID-19 is everywhere but countries with heads of state managing the crisis better seem to have something in common..\n\nGERMANY\n\nNEW ZEALAND\n\nBELGIUM\n\nFINLAND\n\nICELAND\n\nDENMARK\n'},
#  {'id': '115',
#   'labels': ['Appeal to fear/prejudice',
#    'Causal Oversimplification',
#    'Exaggeration/Minimisation',
#    'Loaded Language'],
#   'text': 'PEOPLE KEEP ASKING: "WHY DID GOD TURN HIS BACK ON AMERICA?"\n\nHE DIDN\'T.\nAMERICA TURNED HER BACK ON GOD. \nTHIS IS WHAT THE WORLD LOOKS LIKE WITHOUT HIM.\n'},
#  {'id': '166',
#   'labels': ['Causal Oversimplification'],
#   'text': "COULDN'T WASH HANDS\n\nIS NOW EXTINCT\n"},
#  {'id': '132',
#   'labels': ['Loaded Language'],
#   'text': 'WHAT KIDS THINK COMMUNISM IS\n\nWHAT COMMUNISM REALLY IS\n'},
#  {'id': '1',
#   'labels': ['Causal Oversimplification',
#    'Glittering generalities (Virtue)',
#    'Smears'],
#   'text': '8 YEARS UNDER OBAMA\n4 MILLION JOBS LOST\nUNEMPLOYMENT PEAKED TO 9.9%\nGDP DOWN 2.8%\n\n2 1/2 YEARS UNDER TRUMP\n5.1 MILLION JOBS GAINED\nUNEMPLΟΥΜΕΝΤ FELL TO 3.6%\nGDP UP 3.2%\n'},
#  {'id': '150',
#   'labels': ['Appeal to fear/prejudice',
#    'Exaggeration/Minimisation',
#    'Flag-waving',
#    'Loaded Language',
#    'Name calling/Labeling'],
#   'text': 'THE TWO BIGGEST THREATS TO AMERICA\n\nTHE WORST SENATE LEADER EVER AND THE MOST CORRUPT PRESIDENT EVER\n'},
#  {'id': '165',
#   'labels': ['Appeal to fear/prejudice',
#    'Black-and-white Fallacy/Dictatorship',
#    'Slogans'],
#   'text': 'This is your child with WHOOPING COUGH\n\nVACCINATE your children NOW\n'},
#  {'id': '152',
#   'labels': ['Flag-waving', 'Slogans', 'Smears'],
#   'text': '"Yes, Mr. Trump, let\'s make America great again. But first, get one thing straight: America was great – before you were elected."\n\nBarbra Streisand\n'},
#  {'id': '193',
#   'labels': [],
#   'text': "IT WAS NEVER ABOUT THE VIRUS \n\nIT'S ABOUT SEEING HOW FAR WE CAN PUSH YOU BEFORE YOU PUSH BACK\n"},
#  {'id': '161',
#   'labels': ['Appeal to fear/prejudice',
#    'Black-and-white Fallacy/Dictatorship',
#    'Exaggeration/Minimisation',
#    'Name calling/Labeling',
#    'Reductio ad hitlerum',
#    'Slogans',
#    'Smears',
#    'Thought-terminating cliché'],
#   'text': "HOW DARE YOU NOT VOTERINO FOR HECKIN' BERNERINO?! DON'T YOU KNOW THAT A VOTE FOR BIDEN IS A VOTE FOR FASCISM? THE WORLD IS LITERALLY DYING AND BERNIE-SAMA IS THE ONLY ONE WHO CAN SAVE IT!\n\nhaha hey its the Obama guy\n\nRIDIN WITH BIDEN **2020**"},
#  {'id': '16',
#   'labels': ['Loaded Language', 'Name calling/Labeling', 'Whataboutism'],
#   'text': 'Killed thousands of innocents with drone strikes Received a Nobel Peace\n\nDecided not to retaliate and kill 150 people over an unmanned drone \nCalled a Warmonger\n'},
#  {'id': '72',
#   'labels': ['Name calling/Labeling'],
#   'text': 'SPELLING LESSON\n\nTHE LAST 4 LETTERS IN "AMERICAN": "I CAN!"\n\nTHE LAST 4 LETTERS IN "REPUBLICAN": "I CAN!"\n\nTHE LAST 4 LETTERS IN "DEMOCRATS": RATS!\n'},
#  {'id': '84',
#   'labels': ['Name calling/Labeling'],
#   'text': '"If you tell a lie big enough and keep repeating it, people will eventually come to believe it."\n- Joseph Goebbels, Nazi Propaganda Minister\n\nThe New York Times \nCNN \nBBC\nTIME\nMSNBC\nNBC\nLos Angeles Times\nFox NEWS channel\nnpr\nabc\nCBS NEWS\nThe Washington Post\nUSA TODAY\n'},
#  {'id': '105',
#   'labels': ['Smears'],
#   'text': 'MUST BE AN ELECTION COMING, DEMOCRATS ARE VISITING BLACK COMMUNITIES AGAIN.\n\n'},
#  {'id': '27',
#   'labels': ['Causal Oversimplification', 'Smears'],
#   'text': 'Deaths in the U.S. During a 10 Year Period: 2004 to 2015\n\nDue to Measles\nZERO\nSource: CDC\n\nDue to Measles Vaccines\n108\nSource: VAERS database\n'},
#  {'id': '122',
#   'labels': ['Exaggeration/Minimisation',
#    'Flag-waving',
#    'Loaded Language',
#    "Misrepresentation of Someone's Position (Straw Man)",
#    'Smears'],
#   'text': 'DEMOCRATS HAVE OUTRIGHT STATED THAT THEY WILL OBSTRUCT EVERYTHING THE REPUBLICAN PRESIDENT DOES. \nEVEN IF IT MEANS HARMING AMERICA \nTHEY HAVE PUT PARTY BEFORE COUNTRY AND IT IS UNACCEPTABLE\n'},
#  {'id': '139',
#   'labels': ['Flag-waving',
#    'Loaded Language',
#    'Name calling/Labeling',
#    'Reductio ad hitlerum',
#    'Slogans',
#    'Smears'],
#   'text': 'The Democratic Party IS THE PARTY OF CRIME & EVIL...  A TERRORIST ORGANIZATION WHO HATES AMERICA & AMERICANS\n\nTRAITORS TO AMERICA\n\nTHE COMMUNIST PARTY\n\nSAVE AMERICA SUPPORT TRUMP\n'},
#  {'id': '177',
#   'labels': ['Glittering generalities (Virtue)',
#    'Loaded Language',
#    'Name calling/Labeling',
#    'Smears'],
#   'text': "DON'T FORGET THAT IN JANUARY:\n\nTRUMP FORMED THE CORONAVIRUS TASK FORCE\n\nTHE DEMS WERE WASTING TIME ON A SHAM IMPEACHMENT\n"},
#  {'id': '162',
#   'labels': ['Loaded Language', 'Slogans'],
#   'text': 'TILL DEATH DO US PART\n\nNO TO VIOLENCE AGAINST WOMEN\n'},
#  {'id': '192',
#   'labels': ['Loaded Language', 'Smears'],
#   'text': "If y'all liberals want to tear down monuments to slavery & racism, I have just the monument for you!\n\nDEMOCRATIC NATIONAL HEADQUARTERS\n430 SOUTH CAPITOL STREET\n"},
#  {'id': '134',
#   'labels': ['Loaded Language',
#    'Name calling/Labeling',
#    'Reductio ad hitlerum',
#    'Smears'],
#   'text': "If Trump isn't Hitler, Then l'm a Moron\n\nSelf-awareness\n"},
#  {'id': '196',
#   'labels': ['Exaggeration/Minimisation', 'Smears'],
#   'text': "I'm not pregnant, I haven't been tested. \nBut the President says if it's not tested it's not real. \nI think it's gas..."},
#  {'id': '114',
#   'labels': ['Reductio ad hitlerum'],
#   'text': 'HISTORY HAS SHOWN THAT THESE ARE THE FIRST TWO THINGS BANNED BY TOTALITARIAN GOVERNMENTS'},
#  {'id': '160',
#   'labels': ['Presenting Irrelevant Data (Red Herring)'],
#   'text': 'IF WE DIVIDE 125 GENDERS BY THREE BATHROOMS\n\nHOW MUCH CLIMATE CHANGE DO WE HAVE?'},
#  {'id': '194',
#   'labels': ['Loaded Language', 'Name calling/Labeling'],
#   'text': "Finished 4th in lowa behind an Old Communist, a Gay guy and a Fake Indian!\n\nThere's nothing quite like getting your ass beat by the Village People!"},
#  {'id': '159',
#   'labels': ['Appeal to fear/prejudice',
#    'Causal Oversimplification',
#    'Glittering generalities (Virtue)',
#    'Loaded Language'],
#   'text': 'Do you remember when: Swine Flu Ebola Virus, and Zika Virus Caused mass cancellations?\nCrashed our stock market?\nCaused confusion from misinformation?\nDrove people to stockpile toilet paper?\n\nOf Course not... Because Obama HANDLED that SHIT!\n'},
#  {'id': '123',
#   'labels': ['Slogans', 'Smears'],
#   'text': 'Former Presidents can be IMPEACHED!\nIMPEACH OBAMA!\n'},
#  {'id': '93',
#   'labels': ['Loaded Language'],
#   'text': 'The Real Virus Threatening America\n'},
#  {'id': '120',
#   'labels': ['Appeal to authority',
#    'Black-and-white Fallacy/Dictatorship',
#    'Loaded Language',
#    'Name calling/Labeling'],
#   'text': '"If a law is unjust, a man is not only right to disobey it, he is obligated to do so."\n -Thomas Jefferson\n'},
#  {'id': '143',
#   'labels': ['Loaded Language', 'Name calling/Labeling', 'Smears'],
#   'text': 'THE BULGE IN CONSERVATIVE GIRLS PANTS IS A GUN\n\nTHE BULGE IN LIBERAL GIRLS PANTS IS A PENIS\n'},
#  {'id': '69',
#   'labels': ['Causal Oversimplification',
#    'Smears',
#    'Thought-terminating cliché'],
#   'text': "Transgender man gives birth to non-binary partner's baby with female sperm donor\n\nIf I didn't see it, it didn't happen.\n"},
#  {'id': '14',
#   'labels': ['Loaded Language',
#    "Misrepresentation of Someone's Position (Straw Man)",
#    'Obfuscation, Intentional vagueness, Confusion'],
#   'text': '21 people running for President and only 1 stands against killing babies\n'},
#  {'id': '112',
#   'labels': ['Name calling/Labeling'],
#   'text': "HILLARY CLINTON JOE BIDEN \n\nWEEKEND AT BERNIES'S\n\nHE MAY BE DEAD... BUT HE'S THE LIFE OF THE PARTY!"},
#  {'id': '181',
#   'labels': ['Smears'],
#   'text': '"People are dying who have never died before."\n- Donald J. Trump, March 18, 2020'},
#  {'id': '108',
#   'labels': ['Loaded Language', 'Name calling/Labeling'],
#   'text': "THE PARTY OF 'DIVERSITY'\n\nBLACK WOMAN\nBLACK\nBLACK\nSAMOAN WOMAN\nMEXICAN\nOLD WHITE MILLIONAIRE\n\nFAKE MEXICAN\nMOSTLY GAS\nGALAXY DUST\nTAIWANESE\nGAY\nOLD WHITE MILLIONAIRE"},
#  {'id': '113',
#   'labels': ['Exaggeration/Minimisation', 'Loaded Language'],
#   'text': 'ELEGANT AT LYING\n\nBRUTAL WITH THE TRUTH\n'},
#  {'id': '17',
#   'labels': [],
#   'text': 'THIS IS THE DIFFERENCE BETWEEN 1.4% GDP AND 4.1% GDP\n'},
#  {'id': '136',
#   'labels': ['Exaggeration/Minimisation'],
#   'text': 'WHAT A CONTRAST\n\nFROM WORST EVER TO BEST EVER'},
#  {'id': '91',
#   'labels': ['Appeal to authority', 'Exaggeration/Minimisation', 'Smears'],
#   'text': '"Socialism only works in two places: Heaven where they don\'t need it, and hell where they already have it."\nRonald Regan\n'},
#  {'id': '133',
#   'labels': ['Name calling/Labeling', 'Smears', 'Thought-terminating cliché'],
#   'text': "THAT'S A FACT \n\nDID YOU KNOW THE NRA TRAINED BLACK AMERICANS TO FIGHT AGAINST THE DEMOCRAT FORMED GROUP THE KKK\n"},
#  {'id': '12',
#   'labels': ['Loaded Language', 'Name calling/Labeling'],
#   'text': "TRAITORS\n\nMOSCOW MITCH\n\nMOSCOW'S BITCH\n\n"},
#  {'id': '67',
#   'labels': ['Loaded Language', 'Name calling/Labeling'],
#   'text': 'PEDO TRASH PRETENDING TO BE LIBERTARIAN\n\nPEOPLE THAT UNDERSTAND CONSENT\n\nTHE FUCK OUTTA HERE\n'},
#  {'id': '3',
#   'labels': ['Loaded Language', 'Name calling/Labeling'],
#   'text': "I DIDN'T KNOW THERE WAS A SEXUAL PREDATOR AWARD...\n\nTHANKS DEMOCRATS\n"},
#  {'id': '98',
#   'labels': ['Loaded Language', 'Name calling/Labeling'],
#   'text': "WHEN YOU'RE ANTI TRUMP BUT YOU'RE PRO RAPIST\n\nTHEY ALL KNEW AND\n\n"},
#  {'id': '85',
#   'labels': ['Appeal to fear/prejudice',
#    'Flag-waving',
#    'Loaded Language',
#    'Name calling/Labeling',
#    'Smears',
#    'Whataboutism'],
#   'text': 'KEEP IN MIND THAT DEMOCRATS VOTED TO FINE AMERICAN CITIZENS FOR NOT BUYING INSURANCE, AND THEN CONSPIRED TO GIVE IT TO ILLEGAL ALIENS FOR FREE.\n'},
#  {'id': '137',
#   'labels': ['Exaggeration/Minimisation'],
#   'text': "I'LL NEVER FORGET WHO DID THIS\n\nNO MATTER HOW MUCH FACEBOOK DEFENDS THEM\n"},
#  {'id': '42',
#   'labels': [],
#   'text': 'DEMOCRAT PARTY\n\nNBC\n\nCBS\n\nMSNBC\n\nCNN\n'},
#  {'id': '199',
#   'labels': [],
#   'text': 'A journalist asked Justin Trudeau when more help would arrive for seniors...\n\n...he answered by saying "the priority was on helping other groups of Canadians first."\n'},
#  {'id': '121',
#   'labels': [],
#   'text': "Guess who's waiting for someone else to do all the work lol\n\nBernie\n"},
#  {'id': '53',
#   'labels': ['Thought-terminating cliché'],
#   'text': 'LIBERAL LOGIC: "DON\'T CALL THEM ANIMALS!"\n\n"DON\'T CALL THEM PEOPLE!"\n'},
#  {'id': '49',
#   'labels': ['Loaded Language'],
#   'text': 'WHY DO LIBERALS FIGHT TO KEЕР THESE AND FIGHT TO KILL THESE\n'},
#  {'id': '74',
#   'labels': ['Flag-waving', 'Loaded Language', 'Name calling/Labeling'],
#   'text': "PATRIOTS\n\nWHICH GROUP HELD THE COUNTRY'S INTERESTS OVER THEIR OWN PERSONAL GAIN?\n\nPARASITES\n"},
#  {'id': '118',
#   'labels': ['Loaded Language', 'Name calling/Labeling'],
#   'text': 'Coward\n\nAmerican\n'},
#  {'id': '184',
#   'labels': ['Black-and-white Fallacy/Dictatorship', 'Doubt'],
#   'text': 'Acquiring immunity "the natural way" \n\nAcquiring immunity through vaccination\n\nWhich would you choose?\n'},
#  {'id': '149',
#   'labels': ['Exaggeration/Minimisation',
#    'Loaded Language',
#    "Misrepresentation of Someone's Position (Straw Man)",
#    'Slogans',
#    'Smears'],
#   'text': 'Trump Reportedly Offered A German Firm $1,00,000,000 For Exclusive Rights To Any Coronavirus Vaccine.\n\n"Trump wanted not only to control any new vaccine but also to make sure that it would only be available on a for-profit basis," reported Common Dreams.\n\nWhat could be more depraved than trying to profit off of the suffering of the entire world?\n Spread his shame.'},
#  {'id': '21',
#   'labels': ['Doubt', 'Loaded Language'],
#   'text': 'FREE SPEECH?\n\nHATE SPEECH?\n\nSOMEONE EXPLAIN THIS SHIT...\n\n'},
#  {'id': '111',
#   'labels': ['Exaggeration/Minimisation', 'Smears'],
#   'text': "IF YOU PUT HILLARY'S ARREST ON PAY-PER-VIEW...\n\n...YOU COULD SETTLE THE NATIONAL DEBT!\n\n"},
#  {'id': '190',
#   'labels': ['Appeal to fear/prejudice',
#    'Loaded Language',
#    'Name calling/Labeling',
#    'Smears'],
#   'text': "HI, I'M GEORGE SOROS\nA BILLIONAIRE SOCIOPATHIC GLOBALIST\nI DESTROY ECONOMIES, CULTURES & COUNTRIES\nI PROFIT OFF OF THE DESTRUCTION OF ENTIRE SOCIETIES\nI FINANCE BLACK LIVES MATTER RIOTS\nI AM FUNDING ANTIFA"},
#  {'id': '148',
#   'labels': ['Loaded Language', 'Repetition', 'Slogans'],
#   'text': "VOTE IT OUT\nVOTE IT OUT\n\nHE SAID IT WASN'T REAL.\nHE SAID IT'S CONTAINED.\nHE SAID IT WOULD DISAPPEAR.\nHE BLAMED DEMOCRATS.\nHE SHARED HIS HUNCHES.\nHE OVERRULED HIS SCIENTISTS.\nHE HAS FAILED.\nHE HAS ENDANGERED\nEVERY ONE OF US.\n\nVOTE IT OUT\nVOTE IT OUT\n"},
#  {'id': '10', 'labels': [], 'text': 'DEMOCRATS THEN\n\nDEMOCRATS NOW\n'},
#  {'id': '7',
#   'labels': ['Appeal to authority',
#    'Causal Oversimplification',
#    'Loaded Language',
#    'Name calling/Labeling',
#    'Thought-terminating cliché'],
#   'text': 'HARRY S. TRUMAN\n"YOU CAN\'T GET RICH IN POLITICS UNLESS YOU\'RE A CROOK."\n\nWE KNOW\n'},
#  {'id': '102',
#   'labels': ['Doubt', 'Exaggeration/Minimisation', 'Name calling/Labeling'],
#   'text': 'I HAVE A CHANCE TO BE THE FIRST GAY UNITED STATES PRESIDENT...\n\n...AHH, EXCUSE ME?\n\n'},
#  {'id': '116',
#   'labels': ['Loaded Language', 'Slogans'],
#   'text': 'TRUTH is HATE to those who HATE the TRUTH\n\nTRUTH is LOVE!\n'},
#  {'id': '110',
#   'labels': ['Appeal to fear/prejudice', 'Flag-waving'],
#   'text': 'THE REAL VIRUS THREATENING AMERICA\n'},
#  {'id': '186',
#   'labels': ['Name calling/Labeling'],
#   'text': "This iconic photo of two boys - one vaccinated against smallpox and one who hadn't been vaccinated - was published in 1901, and taken by Dr Allan Warner at the Leicester Isolation Hospital. \n"},
#  {'id': '151',
#   'labels': ['Flag-waving',
#    'Loaded Language',
#    'Name calling/Labeling',
#    'Slogans'],
#   'text': 'ON TUESDAY, NOVEMBER 3, 2020, WE MAKE AMERICA GREAT AGAIN \nBY VOTING THIS NIGHTMARE OUT OF OFFICE!\n\n'},
#  {'id': '92',
#   'labels': ['Appeal to fear/prejudice',
#    'Loaded Language',
#    'Name calling/Labeling'],
#   'text': 'AT LAST, THE ILLEGALS AND ECONOMIC DEADBEATS AND PARASITES HAVE A PRESIDENT ON THEIR MONEY\n\nU.S. DEPARTMENT OF AGRICULTURE\n\nFOOD COUPON\n\nVALUE\n1\nDOLLAR\n\nNON-TRANSFERABLE EXCEPT UNDER CONDITIONS PRESCRIDED BY THE SECRETARY OF AQGRICULTURE\n'},
#  {'id': '78',
#   'labels': ['Loaded Language'],
#   'text': 'ISIS Employee of the Month\n'},
#  {'id': '9',
#   'labels': ['Appeal to fear/prejudice',
#    'Loaded Language',
#    'Name calling/Labeling',
#    'Smears'],
#   'text': '"If that fuckin bastard wins, we\'re all going to hang\nfrom nooses! You better fix this shit!"\nHillary Clinton email to Donna Brazile, DNC Chair, October 17, 2016\n'},
#  {'id': '5',
#   'labels': ['Loaded Language', 'Name calling/Labeling'],
#   'text': 'The Axis of Evil of the United States of America\n'},
#  {'id': '60',
#   'labels': ['Loaded Language'],
#   'text': 'What people think super heroes look like:\n\nWhat super heroes actually look like:\n'},
#  {'id': '163',
#   'labels': ['Black-and-white Fallacy/Dictatorship'],
#   'text': "I GET WHAT I WANT\n\nOR THE COUNTRY DOESN'T GET WHAT IT NEEDS.\n\n"},
#  {'id': '138',
#   'labels': ['Appeal to fear/prejudice',
#    'Flag-waving',
#    'Glittering generalities (Virtue)',
#    'Loaded Language',
#    'Name calling/Labeling'],
#   'text': 'WE OWE ILLEGALS NOTHING\n\nAND OUR VETERANS EVERYTHING'},
#  {'id': '77_batch_2',
#   'labels': ['Causal Oversimplification',
#    'Exaggeration/Minimisation',
#    'Smears',
#    'Thought-terminating cliché'],
#   'text': '2016\n"I\'ve tried to fix the economy for 8 years.\nNothing can fix it.\nTrump can\'t fix it."\n\n2019\n"Trump didn\'t fix the economy; I did. \nIt was my work that fixed the economy, like I planned.\n\n2020\n"Corona didn\'t tank the economy; Trump did.\nNothing can fix it now.\nTrump can\'t fix this."\n'},
#  {'id': '184_batch_2',
#   'labels': [],
#   'text': 'WHAT COVID-19 PROTESTERS THINK WE SEE\n\nWHAT WE REALLY SEE'},
#  {'id': '85_batch_2',
#   'labels': ['Loaded Language', 'Name calling/Labeling'],
#   'text': "ITS NICE TO HAVE A PRESIDENT WITH BALLS AND A 1ST LADY WHO DOESN'T\n"},
#  {'id': '188_batch_2',
#   'labels': ['Slogans', 'Smears'],
#   'text': "It's not that the Majority are silent\n\nIt's that the media are silent about the Majority."},
#  {'id': '107_batch_2',
#   'labels': ['Bandwagon', 'Exaggeration/Minimisation', 'Loaded Language'],
#   'text': "If you support this man, I won't judge you for your choice of political parties. \nI will judge you for your lack of morals, ethics and humanity.\nSo will others.\nSo will history.\n"},
#  {'id': '21_batch_2',
#   'labels': ['Loaded Language'],
#   'text': 'FOR THE LOVE OF GOD ARREST SOMEBODY! \n'},
#  {'id': '86_batch_2',
#   'labels': ['Loaded Language', 'Name calling/Labeling'],
#   'text': "YOU'D THINK YOU WERE IN A WHORE HOUSE, SEEING THIS MANY PUSSIES!\n"},
#  {'id': '70_batch_2',
#   'labels': ['Appeal to fear/prejudice', 'Loaded Language'],
#   'text': 'STORM FORMING IN GULF\nBLAME TRUMP\n\nExpect Dems to castigate him for this, too.\n'},
#  {'id': '32_batch_2',
#   'labels': ['Loaded Language',
#    'Name calling/Labeling',
#    'Smears',
#    'Whataboutism'],
#   'text': 'Charles Wade, BLM Co Founder was arrested in 2016 for Child Sex Trafficking.\nIn other words: He was arrested for Modern Day Slave Trading \nI hope the irony has not been lost on you.'},
#  {'id': '154_batch_2',
#   'labels': [],
#   'text': 'How I feel After "debating" Anti-Vaxxers'},
#  {'id': '178_batch_2',
#   'labels': ['Loaded Language', 'Name calling/Labeling'],
#   'text': 'Surgeons operating with a mask on for 20 hours\n\nKarens shopping with a mask on for 20 minutes'},
#  {'id': '69_batch_2',
#   'labels': [],
#   'text': 'Hostess\nOFFICIAL CAMPAIGN SPONSOR FOR Ding-Dong & HO-HO\n'},
#  {'id': '125_batch_2',
#   'labels': ['Name calling/Labeling'],
#   'text': "I like presidents that don't lose money."},
#  {'id': '179_batch_2',
#   'labels': ['Appeal to fear/prejudice', 'Thought-terminating cliché'],
#   'text': 'ITS BEEN CONFIRMED\n\nBill gates has developed a FACIAL RECOGNITION system that can detect UNVACCINATED INDIVIDUALS. \nthe only way to block it is to wear a face mask'},
#  {'id': '126_batch_2',
#   'labels': ['Flag-waving', 'Loaded Language', 'Slogans', 'Smears'],
#   'text': 'Trump Promised To Make America Great Again. \nFour Years Later...\n\nPANDEMIC\n\nRECESSION\n\nMASS UNEMPLOYMENT\n\nRIOTS\n\nWINNING'},
#  {'id': '26_batch_2',
#   'labels': ['Causal Oversimplification', 'Loaded Language', 'Smears'],
#   'text': "The real reason you're not paying attention to the #childrenslivesmatter or #endchildtrafficking movement is because the mainstream media haven't told you to."},
#  {'id': '23_batch_2',
#   'labels': ['Black-and-white Fallacy/Dictatorship'],
#   'text': "What type of leader do you prefer?\n\nJustin Trudeau at 29\n\nErin O'Toole at 29\n"},
#  {'id': '192_batch_2',
#   'labels': ['Loaded Language', 'Name calling/Labeling'],
#   'text': 'This is what Stupid looks like...'},
#  {'id': '205_batch_2',
#   'labels': ['Name calling/Labeling'],
#   'text': 'STARBUCKS IS NOW OFFERING THESE FREE ISLAMIC DONUTS TO YOUR KIDS\n\nTHE TEXT CALLS FOR SHAKIRA LAW IN AMERICA'},
#  {'id': '180_batch_2',
#   'labels': ['Appeal to fear/prejudice', 'Loaded Language'],
#   'text': "DOLL REPRESENTS HOW MANY VACCINES A CHILD RECEIVES... BY AGE 2\n\nANY QUESTIONS?\n\nYes, we do have a question.\n\nEach doll represents 10,000 children killed by vaccine-preventable diseases every year;\n\nWHY DON'T YOU WANT TO PREVENT DISEASES THAT KILL?"},
#  {'id': '47_batch_2', 'labels': [], 'text': 'Happy Fathers Day\n'},
#  {'id': '164_batch_2',
#   'labels': ['Exaggeration/Minimisation',
#    'Loaded Language',
#    "Misrepresentation of Someone's Position (Straw Man)"],
#   'text': "Anti-vaxxers say The Brady Bunch measles episode is proof that measles was no big deal.\n\nIf you have to get sick, sure can't beat the measles\n\nBy that logic, Hogan's Heroes is proof WW2 POW camps were all just shits and giggles."},
#  {'id': '170_batch_2',
#   'labels': ['Name calling/Labeling'],
#   'text': 'FIRST PHOTO OF THE RUSSIAN VACCINE\n\nSMIRNOFF VODKA\n'},
#  {'id': '196_batch_2',
#   'labels': ['Appeal to fear/prejudice',
#    'Black-and-white Fallacy/Dictatorship',
#    'Loaded Language',
#    'Name calling/Labeling'],
#   'text': 'BETTER TO WAIT IN A LONG LINE TO VOTE FOR TRUMP NOW THAN TO WAIT IN LONG LINES FOR FOOD IN A SOCIALIST AMERICA'},
#  {'id': '186_batch_2',
#   'labels': [],
#   'text': "Don't trust BigPharma!\nRead the insert!\n\nThe inserts are written by BigPharma"},
#  {'id': '104_batch_2',
#   'labels': ['Exaggeration/Minimisation', 'Loaded Language', 'Whataboutism'],
#   'text': "All the squawking about nobody on the left showing empathy for trump's Covid diagnosis. \nTell you what, when he shows an ounce of concern for these kids, we'll think about it!\n"},
#  {'id': '143_batch_2',
#   'labels': ['Exaggeration/Minimisation'],
#   'text': "ANTIVAXXERS LIKE TO SAY DISEASES WERE ENDED\nBY IMPROVED SANITATION.\nLETS TAKE A LOOK AT SOME PLACES WHERE DISEASES HAVE BEEN ERADICATED.\n\nTHIS IS A LOW-INCOME AREA OF MUMBAI, INDIA, WHERE NO ONE GETS POLIO ANYMORE EVER. \nISN'T IT AMAZING WHAT SANITATION CAN DO?"},
#  {'id': '193_batch_2',
#   'labels': [],
#   'text': "I'VE SERVED THIS COUNTRY FOR DECADES.\n\nWHAT IS CHINA"},
#  {'id': '63_batch_2',
#   'labels': ['Exaggeration/Minimisation',
#    'Smears',
#    'Thought-terminating cliché'],
#   'text': "The Democrat ticket is Biden-Harris?\n\nStop, you're gonna make me pee!\n"},
#  {'id': '148_batch_2',
#   'labels': [],
#   'text': 'FINALLY!\nPROOF FOUND THAT VACCINES CONTAIN MERCURY!\n\nX3 Magnification\n\nX30 Magnification\n\nX300 Magnification\n'},
#  {'id': '61_batch_2',
#   'labels': ['Exaggeration/Minimisation', 'Loaded Language', 'Smears'],
#   'text': 'Do you know ANY Democrat who is *enthusiastic* and\n*inspired* that this is their nominee... and thinks this is the best and the brightest they have to offer?\n'},
#  {'id': '113_batch_2',
#   'labels': [],
#   'text': 'Okay, but how will anyone know if they lose their sense of taste?\n'},
#  {'id': '7_batch_2',
#   'labels': ['Loaded Language', 'Name calling/Labeling'],
#   'text': 'The Corrupt Bunch\n'},
#  {'id': '10_batch_2',
#   'labels': ['Appeal to fear/prejudice', 'Loaded Language', 'Smears'],
#   'text': 'This is how thousands were murdered by our government. \nTied to chairs. \nDenied family visits. \nAlone.\nAbandoned.\n\nWhat should we do\nto the government?\n'},
#  {'id': '177_batch_2',
#   'labels': ['Whataboutism'],
#   'text': "Don't forget to tell your surgeon not to wear a mask the next time you need an operation!\n\nBecause apparently masks are ineffective at protecting against germs -- and you definitely don't want your surgeon deprived of oxygen"},
#  {'id': '101_batch_2',
#   'labels': [],
#   'text': "To help Donald Trump get the full COVID-19 experience, let's make sure he loses his job and is evicted from his home next month.\n"},
#  {'id': '13_batch_2',
#   'labels': ['Doubt', 'Loaded Language'],
#   'text': 'The law is not a moral compass. The people who hid Anne Frank were breaking the law.\nThe people who killed her were following it.\n'},
#  {'id': '122_batch_2',
#   'labels': ['Loaded Language', 'Name calling/Labeling', 'Smears'],
#   'text': 'NO HONOR\nNO INTEGRITY\nNO PRINCIPLES\nNO MORALS\nNO PATRIOTISM\nNO HONESTY\nNO ETHICS\nNO CHARACTER\nNO DECENCY\nNO VIRTUE\nNO SCRUPLES\nNO CLASS\nNO HUMANITY\n\n100% TURD'},
#  {'id': '144_batch_2', 'labels': [], 'text': 'Anti-Maskers\n\nGod'},
#  {'id': '45_batch_2',
#   'labels': [],
#   'text': 'IF WE GIVE UP EVERYTHING THAT OFFENDS SOMEONE THIS WILL BE THE ONLY FLAG WE CAN FLY\n'},
#  {'id': '151_batch_2',
#   'labels': ['Loaded Language'],
#   'text': "if the blitz happened in 2020...\n\ni don't consent to this new normal\n\nthere are no bombs you've been brainwashed\n\ni'm going outside its my right\n\nthey want us to stay here to control us\n\ni'm leaving the lights on in my house and you cant stop me"},
#  {'id': '55_batch_2',
#   'labels': ['Loaded Language'],
#   'text': 'I REMEMBER IT ALL SO CLEARLY. \nTHE ENTIRE FAMILY COMMITTED SEXUAL MISCONDUCT ON ME AGAINST MY WISHES!\n'},
#  {'id': '28_batch_2',
#   'labels': ['Loaded Language', 'Name calling/Labeling', 'Smears'],
#   'text': 'Hey everyone check out cokehead Neil Terell.\nPerfect example of the washed up broke liberal.'},
#  {'id': '29_batch_2',
#   'labels': [],
#   'text': 'WHICH ONE ARE YOU?\n\nCHOOSE WISELY BEFORE THEY CHOOSE FOR YOU'},
#  {'id': '100_batch_2',
#   'labels': ['Smears', 'Thought-terminating cliché'],
#   'text': "If Amy Coney Barrett doesn't have the common sense to avoid bringing her 7 kids to a maskless, non socially distanced event then she doesn't have good enough judgment sit on the Supreme Court.\nFull stop.\n"},
#  {'id': '88_batch_2',
#   'labels': ['Causal Oversimplification', 'Loaded Language'],
#   'text': 'BEFORE MY PRESIDENCY THERE WAS NO BLM. \nTHERE WAS NO ANTIFA. \nTHERE WAS NO WAR ON POLICE.\nI BUILT THAT.\n'},
#  {'id': '171_batch_2',
#   'labels': ['Loaded Language',
#    "Misrepresentation of Someone's Position (Straw Man)",
#    'Name calling/Labeling',
#    'Slogans'],
#   'text': 'Americans when Newton discovered gravity :\n\nGravity is communist\n\nWe will not fall down with 9.8m/s^2\n\nМy mass my choice'},
#  {'id': '68_batch_2',
#   'labels': ['Flag-waving', 'Slogans'],
#   'text': 'HEY LIBERALS \nWE CHANGED THE FLAG FOR YOU LIKE IT?\n\nTRUMP\n-2020-\nKEEP AMERICA GREAT!\n\n\n'},
#  {'id': '36_batch_2',
#   'labels': ['Appeal to fear/prejudice',
#    'Black-and-white Fallacy/Dictatorship',
#    'Loaded Language',
#    'Name calling/Labeling'],
#   'text': 'ITS TIME TO TAKE ASTAND FOLKS!\n\nEITHER YOU LET THEM BAN COPS, TEAR DOWN HISTORY, AND SUBVERT YOU INTO SNIVELING COWARDS, OR STAND UP AND TELL THEM TO FUCK OFF!\n'},
#  {'id': '22_batch_2',
#   'labels': ['Loaded Language', 'Name calling/Labeling', 'Whataboutism'],
#   'text': '"Kenosha Mile" Challenge\n\nRun 684 ft, all alone, at night, being chased by a violent mob. \nHave no gear, no spare mags, no backup, no moral patches.\nBe attacked and defend yourself killing only felons, harm no others \nProceed directly to the police taking responsibility for your actions.\nBe witch-hunted as a murderer while your country is burning in riots.\n\nFirst completed by Kyle Rittenhouse, age 17.'},
#  {'id': '130_batch_2', 'labels': [], 'text': 'TRUMP'},
#  {'id': '75_batch_2',
#   'labels': ['Loaded Language', 'Name calling/Labeling'],
#   'text': 'SPECIAL EDITION\n\nDEMOCRATIC NATIONAL CONVENTION 2020\nAMERICAS MOST WANTED\n\nWHERE ALL THE CROOKS COME OUT\n'},
#  {'id': '11_batch_2',
#   'labels': ['Loaded Language', 'Name calling/Labeling'],
#   'text': "Has worked a total of 12 days during the 90 day pandemic so far.\n\nRESIGN\nYou're pathetic!\n"},
#  {'id': '157_batch_2',
#   'labels': [],
#   'text': 'some americans worry vaccines will have microchips to track them\n\ntheir phones:'},
#  {'id': '41_batch_2',
#   'labels': ['Flag-waving',
#    'Glittering generalities (Virtue)',
#    'Loaded Language',
#    'Name calling/Labeling',
#    'Smears'],
#   'text': "TRUDEAU'S PRIORITIES\n1.ENRICHING HIS FRIENDS AND FAMILY\n2. OTHER LIBERAL ELITES AND LOBBYISTS\n3. FOREIGN DICTATORS\n4. CORRUPT CORPORATE EXECUTIVES\n\nERIN'S PRIORITIES\n1. CANADIANS\n\n"},
#  {'id': '58_batch_2',
#   'labels': ['Black-and-white Fallacy/Dictatorship',
#    'Exaggeration/Minimisation'],
#   'text': "IF YOU DONT LISTEN TO DESPACITO YOU AIN'T LATINO\n\n"},
#  {'id': '123_batch_2',
#   'labels': ['Exaggeration/Minimisation',
#    'Loaded Language',
#    'Name calling/Labeling',
#    'Slogans',
#    'Smears'],
#   'text': 'THE JIG IS UP \nThe entire world knows the truth Donnie.\n\nBEHIND ALL THAT ANGER WAS A SAD LITTLE FAILURE OF A MAN WHO TURNED EVERYTHING HE TOUCHED INTO SHIT.'},
#  {'id': '200_batch_2',
#   'labels': ['Glittering generalities (Virtue)'],
#   'text': "DAD WHAT'S LOSING LIKE?\n\nI DON'T KNOW SON, I'M A TRUMP SUPPORTER"},
#  {'id': '152_batch_2',
#   'labels': [],
#   'text': 'In 2021, people who are currently opposed to a non-existant COVID vaccine will tell you "think for yourself" and to "do your own research."'},
#  {'id': '57_batch_2',
#   'labels': ['Loaded Language'],
#   'text': 'IMAGINE IF 50 MILLION BABIES WERE ALLOWED DYING WISHES\n'},
#  {'id': '140_batch_2',
#   'labels': ['Loaded Language', 'Name calling/Labeling', 'Smears'],
#   'text': 'Mitch McConnell - 2016\nTHE AMERICAN PEOPLE SHOULD HAVE A VOICE IN THE SELECTION OF THEIR NEXT SUPREME COURT JUSTICE.\nTHIS VACANCY SHOULD NOT BE FILLED UNTIL WE HAVE A NEW PRESIDENT.\n\nIf you think McConnell will follow his own advice you must be a special kind of stupid.'},
#  {'id': '84_batch_2',
#   'labels': ['Loaded Language', 'Name calling/Labeling', 'Whataboutism'],
#   'text': 'IMAGINE the possibilities if they were to put this much effort into cleaning up blighted communities.\n'},
#  {'id': '203_batch_2',
#   'labels': ['Loaded Language', 'Name calling/Labeling'],
#   'text': "Venezuela's Communist Dictator Nicolas Maduro\n\nBLM Founder Opal Tometi"},
#  {'id': '120_batch_2',
#   'labels': ['Slogans', 'Smears'],
#   'text': "Reportedly Donald Trump Lost $ 1.17 Billion from his\nBusinesses over 10 years from 1985 to 1994!!!\nYou're Fired !!!\n\nSo Basically, Trump isn't actually a successful Businessman -- But he played one recently on TV !"},
#  {'id': '74_batch_2',
#   'labels': [],
#   'text': '"I am enthusiastic for this ticket!" \n- No one\n\n'},
#  {'id': '38_batch_2',
#   'labels': ['Doubt'],
#   'text': 'CAN YOU STILL GET REGULAR SICK OR IS EVERYTHING CORONA\n\n'},
#  {'id': '66_batch_2',
#   'labels': ['Loaded Language'],
#   'text': 'Anyone else want their ass handed to them?\n'},
#  {'id': '202_batch_2',
#   'labels': ['Exaggeration/Minimisation', 'Loaded Language'],
#   'text': "Pray for this man.\n\nHe's fighting a evil that we can't even imagine!"},
#  {'id': '64_batch_2',
#   'labels': ['Smears'],
#   'text': "It's obvious *I* haven't been in a beauty salon lately.\nAnd, besides, they don't work on wigs.\n"},
#  {'id': '182_batch_2',
#   'labels': ['Loaded Language'],
#   'text': "The shocking truth doctors don't want YOU to know!\n\nResearch proves homeopathy cures three conditions!\n\nLow glucose levels\n\nThirst\n\nHeavy wallet syndrome"},
#  {'id': '131_batch_2',
#   'labels': ['Appeal to fear/prejudice', 'Smears'],
#   'text': "BREAKING: Tonight on FOX, Geraldo opens the vault where Trump keeps his healthcare plan.\nSpoiler: It's empty.\n"},
#  {'id': '94_batch_2',
#   'labels': ['Loaded Language', 'Name calling/Labeling'],
#   'text': "They say you can't fix STUPID\nTURNS OUT You Can't QUARANTINE IT EITHER \n"},
#  {'id': '201_batch_2',
#   'labels': ['Loaded Language', 'Smears'],
#   'text': 'WHOEVER REPLACES GINSBURG, RAPED ME IN HIGH SCHOOL.'},
#  {'id': '127_batch_2',
#   'labels': [],
#   'text': 'THIS IS THE LEADING CAUSE OF DEATH IN THE UNITED STATES.'},
#  {'id': '51_batch_2',
#   'labels': ['Exaggeration/Minimisation', 'Name calling/Labeling'],
#   'text': 'One of the hardest most ferocious fighters the world has ever seen, and Mike Tyson.\n'},
#  {'id': '25_batch_2',
#   'labels': ['Causal Oversimplification',
#    'Glittering generalities (Virtue)',
#    'Smears'],
#   'text': "Here's new Conservative leader Erin O'Toole and Justin Trudeau at roughly the same age.\n\nO'Toole signed up for the Canadians Forces while Trudeau was a part-time ski instructor living off a multi-million dollar trust fund.\n\nO'Toole understands regular Canadians because he's always been one of them.\n\nTrudeau will always be out of touch."},
#  {'id': '160_batch_2',
#   'labels': ['Appeal to fear/prejudice',
#    'Causal Oversimplification',
#    "Misrepresentation of Someone's Position (Straw Man)"],
#   'text': "PARENTS REFUSING NEWBORN VITAMIN K SHOTS\n\nBECAUSE THEY'D PREFER BABY HAVE AN ALL NATURAL, ORGANIC INTRACRANIAL HEMORRHAGE"},
#  {'id': '168_batch_2',
#   'labels': ['Black-and-white Fallacy/Dictatorship',
#    'Exaggeration/Minimisation'],
#   'text': 'Wait, what are you doi-\n\nPutin shall be the eternal leader of this world.'},
#  {'id': '103_batch_2',
#   'labels': ['Smears'],
#   'text': 'BURGER KING\n\n"Forget about the Presidency for a moment. \nTrump\'s behavior would get him fired from Applebee\'s."\n'},
#  {'id': '39_batch_2',
#   'labels': ['Doubt'],
#   'text': 'Its time to disband the federal goverment\nCHANGE MY MIND\n'},
#  {'id': '54_batch_2',
#   'labels': ['Loaded Language', 'Name calling/Labeling'],
#   'text': 'It is better to remain silent and be thought a fool than to display one of these on your lawn and remove all doubt.\n\nBIDEN PRESIDENT\n\n'},
#  {'id': '99_batch_2',
#   'labels': ['Loaded Language', 'Name calling/Labeling', 'Smears'],
#   'text': 'An Irresponsible President !\n\nAn Irresponsible Man !!!\n'},
#  {'id': '67_batch_2',
#   'labels': ['Name calling/Labeling'],
#   'text': 'HAIRGATE might have been BARGATE were it not for this woman misreading the sign on the door:\n"Salon" and "Saloon" look very similar to 80-year-old eyes.\n\n'},
#  {'id': '16_batch_2',
#   'labels': [],
#   'text': 'FEDERAL ELECTION\n\nWESTERN CANADA & TERRITORY VOTES\n'},
#  {'id': '82_batch_2',
#   'labels': [],
#   'text': 'Find the differences in these two images\n'},
#  {'id': '8_batch_2',
#   'labels': ['Doubt'],
#   'text': 'IF THE MEDIA WILL LIE ABOUT THIS\n\nWHAT ELSE ARE THEY LYING ABOUT?'},
#  {'id': '145_batch_2',
#   'labels': [],
#   'text': 'You decided not to vaccinate?\n\nClassic mistake.'},
#  {'id': '49_batch_2',
#   'labels': [],
#   'text': 'Trump leaving the hospital Covid free\n'},
#  {'id': '73_batch_2',
#   'labels': [],
#   'text': 'Democrats head for the early-voting precincts.\n\n'},
#  {'id': '199_batch_2',
#   'labels': [],
#   'text': 'PRESIDENTIAL DEBATE VIA SATELLITE\n\nJOE BIDEN'},
#  {'id': '169_batch_2',
#   'labels': ['Name calling/Labeling', 'Smears'],
#   'text': "Hmm. \nThis bridge is only 99.997% safe.\nI think I'll swim.\n\n#AntiVaxxerLogic"},
#  {'id': '198_batch_2',
#   'labels': ['Loaded Language', 'Name calling/Labeling'],
#   'text': 'THEY TOLD ME I COULD BE ANYTHING I WANTED\n\nSO I BECAME THE SAVIOR OF WESTERN CIVILIZATION'},
#  {'id': '12_batch_2', 'labels': [], 'text': "TODAY'S COVID NUMBERS ARE:"},
#  {'id': '156_batch_2',
#   'labels': ['Loaded Language'],
#   'text': 'WARNING !\n\nVaccines may cause...\nLoss or greying of hair\nWrinkles\nGrandparentage\nFree or reduced price bus passes\nTelling kids to get off your lawn\nMoaning about modern music'},
#  {'id': '89_batch_2',
#   'labels': ['Appeal to fear/prejudice',
#    'Loaded Language',
#    'Name calling/Labeling',
#    'Slogans'],
#   'text': "Let's give all police officers 30 days paid vacation to be taken simultaneously, SO idiots like those pictured below can get a taste of what it'd be like to have no\ncops on duty.\n\nDEFUND THE POLICE\n\n"},
#  {'id': '149_batch_2',
#   'labels': [],
#   'text': 'ARE YOU GETTING YOUR SHINGLES VACCINE?\nNO!\n\nDID YOU RECEIVE A SHINGLES VACCINE?\nNO!'},
#  {'id': '50_batch_2',
#   'labels': ['Exaggeration/Minimisation',
#    'Glittering generalities (Virtue)',
#    'Name calling/Labeling'],
#   'text': 'AND JUST LIKE THAT TRUMP GOT THE RONA AND BEAT\nIT OVER THE WEEKEND\n'},
#  {'id': '15_batch_2',
#   'labels': ['Appeal to authority',
#    'Loaded Language',
#    'Name calling/Labeling'],
#   'text': '"It\'s a shame that a leading transparent Western free-market oil and gas producer that was already very focused on ESG is going to be taken offline and their barrels are going to be replaced by barrels of opaque, state-controlled oil from wherever.\nI can just see the Russians rubbing their hands, saying \'this is fantastic."\nPeter Terzakian\nARC Energy Research Institute\n'},
#  {'id': '183_batch_2',
#   'labels': ['Loaded Language',
#    "Misrepresentation of Someone's Position (Straw Man)",
#    'Name calling/Labeling'],
#   'text': "CONSPIRACY THEORIES BECAUSE SANE, LOGICAL EXPLANATIONS AREN'T AS MUCH FUN AS IGNORANT, FEAR-MONGERING LUNACY"},
#  {'id': '44_batch_2',
#   'labels': ['Appeal to fear/prejudice', 'Loaded Language'],
#   'text': 'The ideology that killed over 100 million last century\n\nIs now being praised at our universities today\n\nSA SOCIALIST ALTERNATIVE\nTHE UNIVERSITY OF MELBOURNE\nI WANT FULL COMMUNISM BECAUSE I VALUE A FAIR SOCIETY\nSocialist Alliance\nAustralian National University\n\n'},
#  {'id': '17_batch_2',
#   'labels': ['Doubt', 'Smears'],
#   'text': "THE ROYAL CANADIAN MOUNTED POLICE- WE ALWAYS GET OUR MAN.\n\nUNLESS THAT MAN IS A HIGH RANKING LIBERAL POLITICIAN. THAT'S WHEN WE GO INTO HIDING.\n"},
#  {'id': '206_batch_2', 'labels': [], 'text': 'WHEN A LIBERAL STARTS TALKING'},
#  {'id': '209_batch_2',
#   'labels': ['Doubt'],
#   'text': 'How could you have married that man?\n\nI was going to ask you the same question!\n'},
#  {'id': '210_batch_2',
#   'labels': ['Causal Oversimplification', 'Loaded Language', 'Smears'],
#   'text': "They should first test the covid vaccine on gov't officials.\n\nIf they are safe, the vaccine is good.\nBut if they die, the country is safe."},
#  {'id': '211_batch_2',
#   'labels': ['Flag-waving'],
#   'text': 'OUR CONSTITUTION WAS WRITTEN TO STOP PEOPLE LIKE THESE'},
#  {'id': '212_batch_2',
#   'labels': ['Loaded Language'],
#   'text': 'WHEN YOU ARE SO FULL OF SHIT THAT YOU NEED A SECOND ASSHOLE'},
#  {'id': '213_batch_2',
#   'labels': [],
#   'text': "BREAKING: Massive crowds at biden's rally"},
#  {'id': '214_batch_2',
#   'labels': ['Exaggeration/Minimisation',
#    'Glittering generalities (Virtue)',
#    'Loaded Language',
#    'Thought-terminating cliché'],
#   'text': "THE FIRST PRESIDENT TO EVER FIGHT CHILD SEX TRAFFICKING\n\nIF THAT DOESN'T EARN YOUR VOTE, NOTHING WILL"},
#  {'id': '215_batch_2',
#   'labels': ['Exaggeration/Minimisation', 'Loaded Language'],
#   'text': 'TRUMP SAID THEY ARE FIGHTING AN ANCIENT SEX TRAFFICKING RING AND NOT A SINGLE REPORTER ASKED FOR MORE INFORMATION.\n'},
#  {'id': '216_batch_2',
#   'labels': ['Loaded Language',
#    "Misrepresentation of Someone's Position (Straw Man)",
#    'Smears'],
#   'text': "I BULLSHITTED AND USED BLACKS AND MINORITIES TO GET ELECTED AND DID NOTHING FOR THEM...\n\nNOW I'M ENDORSING JOE BIDEN TO DO THE EXACT SAME THING."},
#  {'id': '219_batch_2',
#   'labels': [],
#   'text': 'The first Black woman vice President and her family.'},
#  {'id': '220_batch_2',
#   'labels': ['Loaded Language'],
#   'text': 'WHO SHIT MY PANTS?'},
#  {'id': '221_batch_2',
#   'labels': [],
#   'text': 'Joey, have you ever rubbed the blonde hair on a grown mans leg?'},
#  {'id': '223_batch_2', 'labels': [], 'text': 'STILL YOUR PRESIDENT'},
#  {'id': '224_batch_2',
#   'labels': ['Name calling/Labeling'],
#   'text': 'ME: “Name your high-level sources."\n\nLIB JOURNO:'},
#  {'id': '225_batch_2',
#   'labels': ['Glittering generalities (Virtue)', 'Loaded Language'],
#   'text': "DONALD, HOW DO YOU SLEEP AT NIGHT KNOWING HOW MANY PEOPLE HATE YOU?\n\nNAKED WITH A SUPER MODEL, AND IT'S MR. PRESIDENT TO YOU."},
#  {'id': '226_batch_2',
#   'labels': [],
#   'text': 'THE MOMENT YOU REGRET THE TRANSITION SURGERY'},
#  {'id': '227_batch_2',
#   'labels': ['Doubt'],
#   'text': "I BET HE'S THINKING ABOUT ANOTHER WOMAN\n\nWHY HAVEN'T THEY ARRESTED HER YET?"},
#  {'id': '228_batch_2',
#   'labels': ['Loaded Language'],
#   'text': 'The picture they show you when you have an erection lasting more than 4 hours\n'},
#  {'id': '229_batch_2',
#   'labels': ['Exaggeration/Minimisation',
#    'Glittering generalities (Virtue)',
#    'Name calling/Labeling'],
#   'text': 'If Trump serves a total of 8 years .. He will have donated his salary of $3,200,000!!\n\n"The most honest man in Washington!"'},
#  {'id': '230_batch_2',
#   'labels': [],
#   'text': '47 MONTHS VS 47 YEARS\n\nYOU DECIDE WHO GOT MORE DONE AND WHO IS THE PROBLEM'},
#  {'id': '231_batch_2',
#   'labels': ['Exaggeration/Minimisation'],
#   'text': "It's just a debate!\nCome on Joe, you can do it."},
#  {'id': '232_batch_2',
#   'labels': ['Name calling/Labeling'],
#   'text': 'NON-ESSENTIAL EMPLOYEE OF THE MONTH 48 YEARS IN A ROW'},
#  {'id': '233_batch_2',
#   'labels': ['Loaded Language'],
#   'text': 'Oh shit look at that we all get treated the same way!! Who knew'},
#  {'id': '234_batch_2',
#   'labels': ['Loaded Language'],
#   'text': 'DEFAMED BY CNN.\nSUES CNN.\nWINS. \nTHEN ROASTS CNN\n...ON CNN'},
#  {'id': '235_batch_2',
#   'labels': [],
#   'text': 'The First Black Lives Matter Meeting!'},
#  {'id': '236_batch_2',
#   'labels': ['Doubt'],
#   'text': 'THE POLITICAL PARTY WHO LOST 33,000 EMAILS WANTS MAIL-IN VOTING?'},
#  {'id': '237_batch_2',
#   'labels': ['Loaded Language', 'Name calling/Labeling'],
#   'text': 'LISTEN UP GROUP\n \nGIVE ME A THUMBS UP IF YOU WANT THE VILLAGE IDIOT "ALEXANDER" BOOTED'},
#  {'id': '238_batch_2',
#   'labels': ['Glittering generalities (Virtue)', 'Smears'],
#   'text': 'Trump loves Miners!\n\nBiden loves Minors!'},
#  {'id': '239_batch_2', 'labels': ['Slogans'], 'text': "ВABY'S LIVES MATTER"},
#  {'id': '240_batch_2',
#   'labels': ['Loaded Language', 'Name calling/Labeling', 'Smears'],
#   'text': "If the democrats really were for women and minorities why did they put an old white guy on top and make her serve him?\nThat sounds extremely racist and sexist, doesn't it?"},
#  {'id': '241_batch_2',
#   'labels': [],
#   'text': 'WHICH AMERICA WILL YOU VOTE FOR\n\nBIDEN\n\nTRUMP'},
#  {'id': '242_batch_2',
#   'labels': ['Loaded Language', 'Name calling/Labeling'],
#   'text': 'Snowflakes begging THIS guy to save them from trolls\n\nThe rest of Earth'},
#  {'id': '244_batch_2',
#   'labels': ['Loaded Language'],
#   'text': 'BREAKING NEWS... SHIT FLOATS!'},
#  {'id': '245_batch_2',
#   'labels': [],
#   'text': "I can't breath in this thing you have no idea how hard this is\n\n(Laughs in MOPP 4)"},
#  {'id': '248_batch_2',
#   'labels': ['Loaded Language'],
#   'text': "PROOF YOU DON'T HAVE TO FLY A PLANE INTO A BUILDING TO DESTROY A NATION!"},
#  {'id': '249_batch_2',
#   'labels': ['Smears'],
# ...
#   'labels': [],
#   'text': "You ain't black!\n\nYou ain't President!\n"},
#  {'id': '673_batch_2',
#   'labels': ['Loaded Language', 'Name calling/Labeling'],
#   'text': 'in order to stay out of Facebook jail I will be posting memes in code\n\nIs a...\n'},
#  {'id': '674_batch_2',
#   'labels': ['Loaded Language', 'Name calling/Labeling', 'Smears'],
#   'text': "Just like Bernie, I'm all for making the minimum age 15.\n\nWage, Joe, the minimum wage, you idiot.\n"},
#  {'id': '675_batch_2', 'labels': [], 'text': 'SNIFF DOG\n'},
#  {'id': '676_batch_2',
#   'labels': ['Name calling/Labeling', 'Smears'],
#   'text': "What now boss?\n\nI'm not your boss this time, Joe.\nThat's Kamala now.\n\n"},
#  {'id': '677_batch_2',
#   'labels': ['Loaded Language', 'Smears'],
#   'text': "Hunter Biden celebrating his dad's victory\n\nPeanutbutter and crack sandwich.\n"},
#  {'id': '678_batch_2',
#   'labels': ['Loaded Language'],
#   'text': 'Pornhub\n\nInterracial couple fuck entire nation.\n\n'},
#  {'id': '679_batch_2',
#   'labels': [],
#   'text': 'TRUMP RALLY\n\nCan you spot the difference?\n\nBIDEN RALLY\n'},
#  {'id': '680_batch_2',
#   'labels': ['Loaded Language', 'Name calling/Labeling'],
#   'text': 'TELLING YOU RIGHT NOW\n\nMY NAME BETTER NOT BE ON YOUR DUMB ASS KIDS COMPUTER\n'},
#  {'id': '681_batch_2',
#   'labels': ['Loaded Language', 'Slogans'],
#   'text': 'During Halloween some states require child sex offenders put signs up... stay informed\n\nBIDEN FOR PRESIDENT\n'},
#  {'id': '682_batch_2',
#   'labels': ['Name calling/Labeling', 'Smears'],
#   'text': 'MEET THE BIDEN BOYS\n\nSNIFF &SNORT\n'},
#  {'id': '683_batch_2',
#   'labels': [],
#   'text': 'TRUMP KIDS CAMPAIGNING FOR DAD\n\nHUNTER BIDEN\n'},
#  {'id': '684_batch_2',
#   'labels': ['Loaded Language', 'Name calling/Labeling'],
#   'text': 'Joe Biden presents\n\nThe Poor Boys\n'},
#  {'id': '685_batch_2',
#   'labels': ['Glittering generalities (Virtue)',
#    'Loaded Language',
#    'Name calling/Labeling'],
#   'text': "President Trump's rallies should feature a wall of mirrors behind him to force the media to show the enormous, enthusiastic crowd in front of him.\n\n"},
#  {'id': '686_batch_2',
#   'labels': ['Glittering generalities (Virtue)', 'Loaded Language'],
#   'text': "I'd crawl blindfolded and naked over a mile of broken glass slathered with germs to vote for Trump and every other Republican on the ballot in 2020.\n"},
#  {'id': '687_batch_2',
#   'labels': ['Smears'],
#   'text': 'Asked what the "D.C." stands for in "Washington, D.C,"\nRep. Alexandria Ocasio-Cortez thought for a moment and replied confidently:\n"Dot Com."\n'},
#  {'id': '688_batch_2',
#   'labels': ['Loaded Language', 'Reductio ad hitlerum'],
#   'text': 'COMMUNISTS AROUND THE GLOBE ARE LOVING THESE 2!'},
#  {'id': '772_batch_2',
#   'labels': ['Loaded Language'],
#   'text': 'There is no voter fraud, we won fair and square\n\nThen you should have nothing to worry about\n\n'},
#  {'id': '773_batch_2',
#   'labels': [],
#   'text': 'WE decide the election.\nNOT the media\n'},
#  {'id': '774_batch_2',
#   'labels': ['Smears'],
#   'text': 'IRAQ HAS BETTER ELECTION SECURITY THAN PENNSYLVANIA.\n'},
#  {'id': '776_batch_2',
#   'labels': [],
#   'text': "I CAN'T BELIEVE THE HISPANICS COST US FLORIDA!\n\nWELL, YOU WERE PEDDLING SOCIALISM TO CUBANS SO..\n\n"},
#  {'id': '777_batch_2',
#   'labels': ['Loaded Language', 'Name calling/Labeling', 'Smears'],
#   'text': "IF YOU THINK FOR ONE SECOND I'M GONNA SURRENDER MY GUNS TO A GOVERNMENT THAT DOESN'T THINK TWICE ABOUT SLAUGHTERING A HELPLESS BABY...\n\nYOU'VE ABSOLUTELY LOST YOUR DAMN MIND!\n"},
#  {'id': '780_batch_2',
#   'labels': [],
#   'text': 'YEA WE GONNA RECOUNT THE GEORGIA BALLOTS\n'},
#  {'id': '784_batch_2',
#   'labels': [],
#   'text': 'MEDIA "PROJECTIONS" ARE NOT ELECTION RESULTS\n'},
#  {'id': '786_batch_2', 'labels': [], 'text': 'Juanita Brazile\n'},
#  {'id': '788_batch_2',
#   'labels': ['Loaded Language', 'Name calling/Labeling'],
#   'text': 'CALM DOWN LITTLE TRUMP HATERS\n\nLET THE SUPREME COURT DO ITS JOB\n'},
#  {'id': '791_batch_2',
#   'labels': [],
#   'text': "Well hi there Kamala, it's been a little while.\n"},
#  {'id': '792_batch_2',
#   'labels': ['Loaded Language', 'Smears'],
#   'text': "I have Indian Blood in me!\n\nImahoe Isn't a tribe\n"},
#  {'id': '793_batch_2', 'labels': [], 'text': 'I GOT YOUR BEHIND.\nAMERICA\n'},
#  {'id': '796_batch_2',
#   'labels': ['Loaded Language', 'Name calling/Labeling'],
#   'text': "I'M WATCHING NEWSMAX AND I HAVEN'T SEEN EITHER OF THESE ASSHOLES ONCE !\n"},
#  {'id': '797_batch_2', 'labels': [], 'text': '000 YOU ALMOST HAD IT\n'},
#  {'id': '800_batch_2',
#   'labels': [],
#   'text': 'REPUBLICANS\n\nAMERICA\n\nDEMOCRATS\n\nCHINA\n\n\n\n\n\n'},
#  {'id': '801_batch_2',
#   'labels': ['Loaded Language', 'Name calling/Labeling'],
#   'text': "SOMEWHERE OUT THERE THERE'S A LIBERAL LOOKING AT MY PAGE JUST LIKE THIS!\n\nEverybody wave at the snowflakes!\n"},
#  {'id': '807_batch_2',
#   'labels': ['Loaded Language', 'Smears'],
#   'text': 'Ten minutes into the campus activist\'s lecture about the "gender spectrum", Murray is slowly beginning to realize why the Church used to burn witches.\n'},
#  {'id': '809_batch_2',
#   'labels': ['Smears'],
#   'text': "It's okay Joe, I was President for a few days too.\n"},
#  {'id': '810_batch_2',
#   'labels': ['Smears'],
#   'text': 'FOX NEWS channel\nOct 7, 1996 - Nov 4, 2020\n\n'},
#  {'id': '811_batch_2',
#   'labels': ['Loaded Language', 'Name calling/Labeling'],
#   'text': '"AND I SAID, IF YOU DON\'T FIND MORE VOTES, WE\'RE NOT GONNA WIN THIS ELECTION.\nWELL, SON OF A BITCH, WE FOUND MORE VOTES."\n\n'},
#  {'id': '812_batch_2',
#   'labels': ['Loaded Language', 'Name calling/Labeling'],
#   'text': 'HAVE YOU ACCEPTED COMMUNISM AS YOUR LORD AND SAVIOR?'},
#  {'id': '820_batch_2',
#   'labels': ['Loaded Language', 'Name calling/Labeling', 'Smears'],
#   'text': 'FAKE NEWS BESTSELLER\n\nTHE ART OF THE STEAL JOE BIDEN'},
#  {'id': '821_batch_2',
#   'labels': [],
#   'text': 'HERE TO COLLECT MY REPARATIONS CHECK'},
#  {'id': '823_batch_2',
#   'labels': ['Loaded Language', 'Name calling/Labeling'],
#   'text': "That's a nice business you got there. \nBe a shame if someone...\n\nCLOSED IT"},
#  {'id': '834_batch_2',
#   'labels': ['Loaded Language'],
#   'text': "YOU DIDN'T LOCK ANY OF US UP BEFORE THE ELECTION AND YOU THOUGHT IT WOULD BE EVEN REMOTELY FAIR\n"},
#  {'id': '836_batch_2',
#   'labels': ['Loaded Language', 'Smears'],
#   'text': 'FOX NEWS IS GOING LEFT\n\nFOX NEWS SUCKS!\n\nWALK AWAY'},
#  {'id': '851_batch_2',
#   'labels': ['Loaded Language', 'Name calling/Labeling', 'Smears'],
#   'text': '4,634 people died of Covid in China. \nTotal.\n\nWe\'re at 177,000 and climbing.\nDon\'t call it the "China virus".\nThis sh*t is the "Trump Mumps".'},
#  {'id': '853_batch_2',
#   'labels': ['Loaded Language', 'Smears'],
#   'text': 'Organized Religion\n\nBecause nothing feeds the hungry, helps the poor or takes care of the sick like spending 1.1 million dollars\nto build a 198 foot steel cross.'},
#  {'id': '859_batch_2',
#   'labels': ['Loaded Language', 'Name calling/Labeling'],
#   'text': 'Long after this moron is dead\n\nHistory will remember the cowards who kept quiet and let this go on'},
#  {'id': '861_batch_2',
#   'labels': ['Smears'],
#   'text': 'Trump should move the GOP convention to the Kremlin. \nThat way all the party can attend & get the kind of TV news they like.'},
#  {'id': '863_batch_2',
#   'labels': ['Loaded Language', 'Name calling/Labeling', 'Smears'],
#   'text': "What's more likely?\nPutin wanted Trump to win because he liked him... or because he knew Trump was weak and stupid."},
#  {'id': '867_batch_2',
#   'labels': ['Name calling/Labeling', 'Smears'],
#   'text': "AT THIS POINT, SHOULDN'T HIS RALLIES BE CONSIDERED A FAREWELL TOUR?"},
#  {'id': '868_batch_2',
#   'labels': ['Loaded Language'],
#   'text': 'WE OWNED THE LIBS!!!\n\nHELL YEAH WE DID!!!\n'},
#  {'id': '869_batch_2',
#   'labels': ['Loaded Language', 'Name calling/Labeling', 'Smears'],
#   'text': 'He acted faster against the imaginary threat of caravans than the actual threat of coronavirus.'},
#  {'id': '874_batch_2',
#   'labels': ['Loaded Language', 'Smears'],
#   'text': "AFTER TRUMP IS GONE, ONE OF THE THINGS I'M GOING TO REMEMBER IS THE COWARDICE OF PEOPLE WHO WENT ALONG."},
#  {'id': '879_batch_2',
#   'labels': ['Loaded Language', 'Name calling/Labeling', 'Smears'],
#   'text': "Did you hear Trump in today's briefing when he offered his heartfelt sympathy for the families who've lost loved ones to coronavirus?\n\nYeah, Me Neither"},
#  {'id': '882_batch_2',
#   'labels': ['Loaded Language', 'Name calling/Labeling', 'Smears'],
#   'text': "Don't Listen To this completely unstable moron.\nHe only cares about $$$ and his imminent loss in 2020.\nListen to Me Only Not The Moron Next To Me"},
#  {'id': '884_batch_2',
#   'labels': ['Name calling/Labeling'],
#   'text': "PRESIDENT'S DAY SPECIAL\n\nWHITE RUSSIAN + CHEETOS"},
#  {'id': '885_batch_2',
#   'labels': [],
#   'text': "PRESIDENTS' DAY SALE\n\nEVERYONE MUST GO"},
#  {'id': '890_batch_2',
#   'labels': [],
#   'text': 'When you ask where all the money went'},
#  {'id': '892_batch_2',
#   'labels': ['Loaded Language', 'Name calling/Labeling'],
#   'text': 'Let\'s have illegal immigrants hunt down sex offenders for a chance at citizenship. We\'ll call it "Aliens VS Predators"\n'},
#  {'id': '896_batch_2', 'labels': [], 'text': 'IF 2020 WAS A PRIME MINISTER'},
#  {'id': '898_batch_2',
#   'labels': ['Loaded Language', 'Smears'],
#   'text': 'POLICE SHOULD INVESTIGATE COVID FRAUD NOT PERSECUTE THOSE WHO DO THEIR JOB FOR THEM'},
#  {'id': '899_batch_2',
#   'labels': ['Name calling/Labeling'],
#   'text': 'STOP LOOKING AT GUNS YOU ALREADY HAVE 20\n\nWHY CANT YOU JUST LOOK AT PORN LIKE A NORMAL MAN'},
#  {'id': '907_batch_2',
#   'labels': ['Loaded Language', 'Name calling/Labeling', 'Smears'],
#   'text': "THE PROBLEM IS NOT THAT TRUDEAU IS AN INCOMPETENT, ENTITLED, LYING, VIRTUE SIGNALING, BACKSTABBING, FAKE, IDIOT, WHO HAS NO BUSINESS\nLEADING A COUNTRY.\n\nTHE PROBLEM IS HIS SUPPORTERS DON'T CARE."},
#  {'id': '908_batch_2',
#   'labels': ['Loaded Language'],
#   'text': 'IF YOU GO TO A PARTY, YOU WILL GO TO JAIL BECAUSE CORONAVIRUS\n\n\nIF YOU ARE IN JAIL, WE WILL LET YOU OUT BECAUSE CORONAVIRUS'},
#  {'id': '913_batch_2',
#   'labels': ['Loaded Language', 'Smears'],
#   'text': 'Неу Joe Biden Fuck you'},
#  {'id': '922_batch_2', 'labels': [], 'text': 'Who built the cages, Joe?\n'},
#  {'id': '923_batch_2',
#   'labels': ['Loaded Language'],
#   'text': 'New Walmart greeter...bless his heart\n\nWELCOME TO TARGET'},
#  {'id': '924_batch_2',
#   'labels': ['Loaded Language', 'Smears'],
#   'text': 'HUNTER BIDEN SAYS WHITE LINES MATTER'},
#  {'id': '930_batch_2',
#   'labels': ['Loaded Language', 'Smears'],
#   'text': "IF YOU LIKE SUBPOENA COLADAS AND GETTING CAUGHT IN UKRAIN WHEN YOUR DAD'S INTO CHILDREN AND YOU ARE INTO COCAIN"},
#  {'id': '931_batch_2',
#   'labels': ['Loaded Language', 'Smears'],
#   'text': 'Chinese businessman arrested for operating illegal casino in $9 million mansion in Toronto\n\nWei met with Justin twice and gave $1 million to the Trudeau Foundation'},
#  {'id': '946_batch_2',
#   'labels': [],
#   'text': 'Anti-vaxxers\n\nSelf-Perception\n\nReality'},
#  {'id': '947_batch_2',
#   'labels': [],
#   'text': 'Human 1350g\n\nChimpanzee 400g\n\nOrangutan 400g\n\n"I\'ve done my own research"'},
#  {'id': '949_batch_2',
#   'labels': ['Loaded Language', 'Name calling/Labeling'],
#   'text': 'ANTIVAX\n\n"ANTIVAX"\n\n"FUCKING IDIOT'},
#  {'id': '950_batch_2',
#   'labels': ['Name calling/Labeling'],
#   'text': 'I SAW YOU SHARE ANTI-VAX MEMES\n\nYOU ARE GETTING A SCIENCE TEXTBOOK THIS YEAR'},
#  {'id': '951_batch_2',
#   'labels': [],
#   'text': 'A microchipping syringe\n\nA vaccine syringe\n\nANY QUESTIONS?'},
#  {'id': '954_batch_2',
#   'labels': [],
#   'text': "Are you taking me to the hospital?\n\nNo ma'am, you need top medical experts. \nWe're taking you to the comments section."},
#  {'id': '958_batch_2',
#   'labels': [],
#   'text': "MAYBE COURT DECISIONS JUST ISN'T YOUR GAME KNOW LET'S HAVE A SPELLING CONTEST"},
#  {'id': '959_batch_2',
#   'labels': ['Loaded Language', 'Name calling/Labeling'],
#   'text': "MAYBE ELECTIONS AREN'T YOUR GAME, TRUMP CULTISTS\n\nI KNOW...LET'S HAVE A SPELLING CONTEST."},
#  {'id': '960_batch_2',
#   'labels': ['Smears'],
#   'text': 'Taiwan:\nPopulation: 23.78 million\nCases: 553\nDeaths: 7\n\nFlorida:\nPopulation: 21.48 million\nCases: 795,000\nDeaths: 16,647\n\nNearly identical population, opposite response.'},
#  {'id': '962_batch_2',
#   'labels': ['Name calling/Labeling', 'Smears'],
#   'text': 'CNN PROJECTION\nDONALD TRUMP WINS THE STATE OF DENIAL'},
#  {'id': '963_batch_2',
#   'labels': ['Loaded Language', 'Name calling/Labeling', 'Smears'],
#   'text': 'If Democrats had "rigged the election" these 4 morons wouldn\'t have won reelection.'},
#  {'id': '964_batch_2',
#   'labels': ['Loaded Language'],
#   'text': 'Just remember:\nWhen we dump Trump, they all go too.'},
#  {'id': '970_batch_2',
#   'labels': ['Loaded Language', 'Smears'],
#   'text': 'THE MORAL OF THE STORY IS, HE LIED TO YOU FOR MONTHS AND ENCOURAGED YOU TO LIVE RECKLESSLY\nDURING A PANDEMIC, AND WHEN IT GOT TO HIM HE RECEIVED EVERY TOP TIER TREATMENT AND MEDICATION TO ENSURE HIS SURVIVAL WHILE YOUR FRIENDS AND FAMILY DIED ALONE.\n\nREMEMBER THAT ON NOV 3RD.'},
#  {'id': '972_batch_2',
#   'labels': ['Name calling/Labeling', 'Smears'],
#   'text': 'TRUMPKIN\nOrange on the outside, Hollow on the inside, and should be thrown out in November'},
#  {'id': '980_batch_2',
#   'labels': ['Loaded Language'],
#   'text': 'THE FACE YOU MAKE WHEN YOU REALIZE "JUST COMPLY AND DON\'T RESIST" APPLIES TO YOU TOO'},
#  {'id': '983_batch_2',
#   'labels': ['Loaded Language', 'Smears'],
#   'text': "Let me repeat this for those that didn't hear me!\n\nThis is the First Time EVER, that the justice department has defended a RAPE case instead of prosecuting it!"},
#  {'id': '985_batch_2',
#   'labels': ['Loaded Language', 'Name calling/Labeling'],
#   'text': 'TRUMP IS GONNA FIX\n\nTHE SHITTY JOB THE CURRENT PRESIDENT IS DOING'},
#  {'id': '987_batch_2',
#   'labels': ['Loaded Language'],
#   'text': "Trump didn't make America racist...\n\nHe made the racists feel comfortable enough to show their faces in public."},
#  {'id': '989_batch_2',
#   'labels': ['Loaded Language', 'Name calling/Labeling'],
#   'text': "For all those posting pictures of Kyle Rittenhouse cleaning graffiti, here's a picture of Ted Bundy doing the dishes. \nThe ability to clean doesn't exclude someone from being a murderer."},
#  {'id': '475_batch_2',
#   'labels': [],
#   'text': 'DR. FAUCI : Have a fan implanted to your head to blow the COVID-19 virus away from your face\n'},
#  {'id': '477_batch_2',
#   'labels': [],
#   'text': '"YOU WON\'T TAKE MY CHIP WITH A PATENT NUMBER 060606?"\n\n"HOW DARE YOU!"\n'},
#  {'id': '487_batch_2',
#   'labels': [],
#   'text': "Rep Jerry Nadler in car accident!\n\nIT WASN'T ME"},
#  {'id': '494_batch_2',
#   'labels': ['Loaded Language', 'Name calling/Labeling', 'Smears'],
#   'text': 'AOC after getting called a bitch:\nThe attempt on my life has left me scarred and deformed'},
#  {'id': '498_batch_2',
#   'labels': [],
#   'text': 'I would have never voted for me!!!'},
#  {'id': '501_batch_2',
#   'labels': ['Smears'],
#   'text': 'HOW TO KILL THE CORONOVIRUS...\nHey Hillary, I hear the Coronavirus is going to testify against you.'},
#  {'id': '508_batch_2',
#   'labels': [],
#   'text': "LOOK, WHEN I'M IN THE WAFFLE HOUSE, I'M GOING TO...\nWHITE HOUSE, HONEY WHITE HOUSE"},
#  {'id': '509_batch_2',
#   'labels': ['Loaded Language', 'Name calling/Labeling'],
#   'text': "I support MLB\n\nIt's BLM you idiot"},
#  {'id': '510_batch_2',
#   'labels': ['Loaded Language'],
#   'text': 'PELOSI ENDORSES BIDEN\n"He is a leader who is the personification of hope and courage, values, authenticity, and integrity."\n\nTHANK YOU.\n\nI SAID NO LICKING.'},
#  {'id': '512_batch_2',
#   'labels': ['Loaded Language', 'Name calling/Labeling', 'Smears'],
#   'text': "IF YOU TRUST SOMEONE WHO HAS\n\n500,000 SHARES WITH MONSANTO\nINJURED THOUSANDS OF PEOPLE WITH VACCINES\nPLANS TO BLOCK OUT THE SUN\nADVOCATED FOR MICROCHIPPING\nSPONSORED MARINA ABRAMOVIC\n\nYOU'RE A SPECIAL KIND OF STUPID"}]

# %%
len(data_train)
# Out:
# 688

# %%
labels_train = []
for da in data_train:
    labels_train.append(da['labels'])
labels_train
# Out:
# 688

# %%
    
count_train = 0
for label in labels_train:
    if len(label)== 0:
        count_train += 1
    
count_train
# Out:
# 143
